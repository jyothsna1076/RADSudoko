# %% [markdown]
# <a href="https://colab.research.google.com/github/jyothsna1076/RADSudoko/blob/master/RandomForestPRML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.model_selection import train_test_split
np.random.seed(42)
df= pd.read_csv("Train_data.csv")
def le(df):
    for col in df.columns:
        if df[col].dtype == 'object':
                label_encoder = LabelEncoder()
                df[col] = label_encoder.fit_transform(df[col])

le(df)
x=  df.drop("class",axis= 1)
y= df["class"]
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size= 0.2, random_state= 42)

# %%
from collections import Counter

class MyRandomForest:
    def __init__(self, n_trees=10,sample_ratio=0.3, max_depth=None, n_features=None):
        self.n_trees = n_trees
        self.max_depth = max_depth
        self.sample_ratio = sample_ratio
        self.n_features = n_features
        self.trees = []

    def bootstrap_sample(self, X, y):
        n_samples = X.shape[0]
        indices = np.random.choice(n_samples, int(n_samples* self.sample_ratio), replace=True)
        return X.iloc[indices], y.iloc[indices]

    def fit(self, X, y):
        self.trees = []
        for _ in range(self.n_trees):
            X_sample, y_sample = self.bootstrap_sample(X, y)
            tree = DecisionTreeClassifier(
                max_depth=self.max_depth,
                max_features=self.n_features,
                # random_state= 42
            )
            tree.fit(X_sample, y_sample)
            # plt.figure(figsize=(30, 20))
            # plot_tree(tree)
            # plt.show()
            self.trees.append(tree)

    def predict(self, X):
        tree_predictions = np.array([tree.predict(X) for tree in self.trees])
        final_predictions = []

        for sample_preds in tree_predictions.T:
            # Majority vote
            vote = Counter(sample_preds).most_common(1)[0][0]
            final_predictions.append(vote)

        return np.array(final_predictions)

# %% [markdown]
# Row Sampling

# %%
# rf = MyRandomForest(n_trees=5, max_depth=None, n_features=None)

# # Fit the model on your dataset
# rf.fit(x_train, y_train)

# # Predict
# y_pred = rf.predict(x_test)

# # Evaluate
# from sklearn.metrics import accuracy_score
# print("Accuracy on your dataset:", accuracy_score(y_test, y_pred))

# %%
# def run_experiment(X, y, sample_ratio=0.3, max_depth=None, test_size=0.2):
#     x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size, random_state=42)

#     accuracies = []

#     for n_trees in range(1,15):
#         model = MyRandomForest(n_trees=n_trees, sample_ratio=sample_ratio, max_depth=max_depth,n_features=None)
#         model.fit(x_train, y_train)
#         preds = model.predict(x_test)
#         acc = accuracy_score(y_test, preds)
#         accuracies.append(acc)
#         print(f"{n_trees} trees → Accuracy: {acc:.4f}")

#     # Plot
#     plt.figure(figsize=(10, 5))
#     plt.plot(range(1, 15), accuracies, marker='o')
#     plt.xlabel("Number of Trees")
#     plt.ylabel("Accuracy")
#     plt.title(f"Accuracy vs. Number of Trees (sample_ratio={sample_ratio}, max_depth={max_depth})")
#     plt.grid(True)
#     plt.show()

# %%
# run_experiment(x,y)

# %%
# def experiment_sampling_effect(X, y, tree_count=10, max_depth=None, test_size=0.2):
#     sample_ratios = np.linspace(0.1, 1.0, 10)  # 10 values from 0.1 to 1.0
#     accuracies = []

#     # Train-test split
#     # x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

#     for ratio in sample_ratios:
#         model = MyRandomForest(n_trees=tree_count, sample_ratio=ratio, max_depth=max_depth)
#         model.fit(x_train, y_train)
#         preds = model.predict(x_test)
#         acc = accuracy_score(y_test, preds)
#         accuracies.append(acc)
#         print(f"Sampling Ratio: {ratio:.2f} → Accuracy: {acc:.4f}")

#     # Plotting
#     plt.figure(figsize=(10, 5))
#     plt.plot(sample_ratios, accuracies, marker='o')
#     plt.xlabel("Sampling Ratio (Fraction of Training Data per Tree)")
#     plt.ylabel("Accuracy")
#     plt.title(f"Accuracy vs. Sampling Ratio (Trees={tree_count}, max_depth={max_depth})")
#     plt.grid(True)
#     plt.show()

# %%
# experiment_sampling_effect(x,y)

# %%
# def experiment_depth_effect(X, y, n_trees=10, sample_ratio=0.3, test_size=0.2):
#     depths = list(range(1, 16))  # max_depth from 1 to 15
#     accuracies = []

#     # Train-test split
#     x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

#     for depth in depths:
#         model = MyRandomForest(n_trees=n_trees, sample_ratio=sample_ratio, max_depth=depth)
#         model.fit(x_train, y_train)
#         preds = model.predict(x_test)
#         acc = accuracy_score(y_test, preds)
#         accuracies.append(acc)
#         print(f"Depth: {depth} → Accuracy: {acc:.4f}")

#     # Plotting
#     plt.figure(figsize=(10, 5))
#     plt.plot(depths, accuracies, marker='o')
#     plt.xlabel("Max Depth of Trees")
#     plt.ylabel("Accuracy")
#     plt.title(f"Accuracy vs. Tree Depth (Trees={n_trees}, sample_ratio={sample_ratio})")
#     plt.grid(True)
#     plt.show()

# %%
# experiment_depth_effect(x,y)

# %%
# from itertools import product

# def grid_search_rf(X, y, sample_ratios, tree_counts, depths, test_size=0.2):
#     best_acc = 0
#     best_params = None
#     results = []

#     x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

#     for sample_ratio, n_trees, max_depth in product(sample_ratios, tree_counts, depths):
#         model = MyRandomForest(n_trees=n_trees, sample_ratio=sample_ratio, max_depth=max_depth)
#         model.fit(x_train, y_train)
#         preds = model.predict(x_test)
#         acc = accuracy_score(y_test, preds)
#         results.append((acc, sample_ratio, n_trees, max_depth))
#         # print(f"Sample: {sample_ratio}, Trees: {n_trees}, Depth: {max_depth} → Accuracy: {acc:.4f}")

#         if acc > best_acc:
#             best_acc = acc
#             best_params = (sample_ratio, n_trees, max_depth)

#     print("\nBest Configuration:")
#     print(f"Sample Ratio: {best_params[0]}, Trees: {best_params[1]}, Max Depth: {best_params[2]} → Accuracy: {best_acc:.4f}")

#     return best_params

# %%
# sample_ratios = [0.3, 0.5, 0.7]
# n_trees_options = [5, 10, 15]
# max_depths = [3, 5, 10, None]

# %%
import joblib
# best_sample, best_trees, best_depth = grid_search_rf(x, y, sample_ratios, n_trees_options, max_depths)
best_sample=0.5
best_trees= 15
best_depth = None
final_model = MyRandomForest(n_trees=best_trees, sample_ratio=best_sample, max_depth=best_depth)
final_model.fit(x_train, y_train)


joblib.dump(final_model, 'final_model.pkl')
# print(f"Final Model Accuracy: {final_acc:.4f}")
# Out:
# ['final_model.pkl']

# %%
# model = joblib.load('final_model.pkl')
# final_preds = model.predict(x_test)
# final_acc = accuracy_score(y_test, final_preds)
# print(f"Final Model Accuracy: {final_acc:.4f}")
# Out:
# Final Model Accuracy: 0.9978

# %% [markdown]
# Column Sampling

# %%
# class MyRandomForest_comb:
#     def __init__(self, n_trees=10, sample_ratio=0.3, max_depth=None, n_features=None, combined_sampling=False):
#         self.n_trees = n_trees
#         self.sample_ratio = sample_ratio
#         self.max_depth = max_depth
#         self.n_features = n_features
#         self.combined_sampling = combined_sampling
#         self.trees = []
#         self.feature_indices_per_tree = []

#     def bootstrap_sample(self, X, y):
#         n_samples = X.shape[0]
#         indices = np.random.choice(n_samples, int(n_samples * self.sample_ratio), replace=True)
#         return X.iloc[indices], y.iloc[indices]

#     def sample_features(self, X):
#         n_total_features = X.shape[1]
#         if self.n_features is None or self.n_features > n_total_features:
#             selected_features = list(range(n_total_features))
#         else:
#             selected_features = np.random.choice(n_total_features, self.n_features, replace=False)
#         return sorted(selected_features)

#     def fit(self, X, y):
#         self.trees = []
#         self.feature_indices_per_tree = []

#         for _ in range(self.n_trees):
#             X_sample, y_sample = self.bootstrap_sample(X, y)

#             if self.combined_sampling or self.n_features is not None:
#                 selected_features = self.sample_features(X_sample)
#                 X_sample = X_sample.iloc[:, selected_features]
#                 self.feature_indices_per_tree.append(selected_features)
#             else:
#                 self.feature_indices_per_tree.append(None)

#             tree = DecisionTreeClassifier(
#                 max_depth=self.max_depth,
#                 random_state=None
#             )
#             tree.fit(X_sample, y_sample)
#             self.trees.append(tree)

#     def predict(self, X):
#         tree_predictions = []

#         for tree, feature_idx in zip(self.trees, self.feature_indices_per_tree):
#             if feature_idx is not None:
#                 X_selected = X.iloc[:, feature_idx]
#             else:
#                 X_selected = X
#             tree_predictions.append(tree.predict(X_selected))

#         # Majority vote
#         tree_predictions = np.array(tree_predictions).T
#         final_predictions = [Counter(row).most_common(1)[0][0] for row in tree_predictions]

#         return np.array(final_predictions)

# %%
# # Column Sampling Only
# rf_column = MyRandomForest_comb(n_trees=10, sample_ratio=1.0, max_depth=5, n_features=10)
# rf_column.fit(x_train, y_train)
# print("Column Sampling Accuracy:", accuracy_score(y_test, rf_column.predict(x_test)))

# # Combined Row + Column Sampling
# rf_combined = MyRandomForest_comb(n_trees=10, sample_ratio=0.5, max_depth=5, n_features=10, combined_sampling=True)
# rf_combined.fit(x_train, y_train)
# print("Combined Sampling Accuracy:", accuracy_score(y_test, rf_combined.predict(x_test)))

# %%
# def experiment_depth_effect_comb(X, y, n_trees=10, sample_ratio=1.0, n_features=None, combined_sampling=False, test_size=0.2):
#     depths = list(range(1, 16))  # max_depth from 1 to 15
#     accuracies = []

#     x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

#     for depth in depths:
#         model = MyRandomForest_comb(n_trees=n_trees, sample_ratio=sample_ratio, max_depth=depth,
#                                n_features=n_features, combined_sampling=combined_sampling)
#         model.fit(x_train, y_train)
#         preds = model.predict(x_test)
#         acc = accuracy_score(y_test, preds)
#         accuracies.append(acc)
#         print(f"Depth: {depth} → Accuracy: {acc:.4f}")

#     plt.figure(figsize=(10, 5))
#     plt.plot(depths, accuracies, marker='o')
#     plt.xlabel("Max Depth of Trees")
#     plt.ylabel("Accuracy")
#     plt.title(f"Accuracy vs. Tree Depth (Trees={n_trees}, Sampling={sample_ratio}, Features={n_features})")
#     plt.grid(True)
#     plt.show()

# %%
# def experiment_feature_count_effect_comb(X, y, n_trees=10, sample_ratio=1.0, max_depth=None, test_size=0.2):
#     total_features = X.shape[1]
#     feature_counts = list(range(1, total_features + 1, max(1, total_features // 10)))  # Steps of ~10%
#     accuracies = []

#     x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

#     for n_feats in feature_counts:
#         model = MyRandomForest_comb(n_trees=n_trees, sample_ratio=sample_ratio, max_depth=max_depth,
#                                n_features=n_feats, combined_sampling=True)
#         model.fit(x_train, y_train)
#         preds = model.predict(x_test)
#         acc = accuracy_score(y_test, preds)
#         accuracies.append(acc)
#         print(f"Features: {n_feats} → Accuracy: {acc:.4f}")

#     plt.figure(figsize=(10, 5))
#     plt.plot(feature_counts, accuracies, marker='o')
#     plt.xlabel("Number of Features Sampled")
#     plt.ylabel("Accuracy")
#     plt.title(f"Accuracy vs. Number of Features (Trees={n_trees}, Sample Ratio={sample_ratio})")
#     plt.grid(True)
#     plt.show()

# %%
# def experiment_tree_count_effect_comb(X, y, sample_ratio=1.0, max_depth=None, n_features=None,
#                                  combined_sampling=False, test_size=0.2):
#     tree_counts = list(range(1, 16))  # Trees from 1 to 15
#     accuracies = []

#     x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

#     for n_trees in tree_counts:
#         model = MyRandomForest_comb(n_trees=n_trees, sample_ratio=sample_ratio, max_depth=max_depth,
#                                n_features=n_features, combined_sampling=combined_sampling)
#         model.fit(x_train, y_train)
#         preds = model.predict(x_test)
#         acc = accuracy_score(y_test, preds)
#         accuracies.append(acc)
#         print(f"Trees: {n_trees} → Accuracy: {acc:.4f}")

#     plt.figure(figsize=(10, 5))
#     plt.plot(tree_counts, accuracies, marker='o')
#     plt.xlabel("Number of Trees")
#     plt.ylabel("Accuracy")
#     plt.title(f"Accuracy vs. Number of Trees (Depth={max_depth}, Features={n_features})")
#     plt.grid(True)
#     plt.show()

# %%
# from itertools import product

# def grid_search_rf_comb(X, y, sample_ratios, tree_counts, depths, n_features_list, test_size=0.2, combined_sampling=True):
#     best_acc = 0
#     best_params = None
#     results = []

#     x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

#     for sample_ratio, n_trees, max_depth, n_features in product(sample_ratios, tree_counts, depths, n_features_list):
#         model = MyRandomForest_comb(n_trees=n_trees, sample_ratio=sample_ratio, max_depth=max_depth,
#                                n_features=n_features, combined_sampling=combined_sampling)
#         model.fit(x_train, y_train)
#         preds = model.predict(x_test)
#         acc = accuracy_score(y_test, preds)
#         results.append((acc, sample_ratio, n_trees, max_depth, n_features))
#         print(f"Sample: {sample_ratio}, Trees: {n_trees}, Depth: {max_depth}, Features: {n_features} → Accuracy: {acc:.4f}")

#         if acc > best_acc:
#             best_acc = acc
#             best_params = (sample_ratio, n_trees, max_depth, n_features)

#     print("\n Best Configuration:")
#     print(f"Sample Ratio: {best_params[0]}, Trees: {best_params[1]}, Max Depth: {best_params[2]}, Features: {best_params[3]} → Accuracy: {best_acc:.4f}")

#     return best_params

# %%
# # Example usage for each:
# experiment_depth_effect_comb(x, y, n_trees=10, sample_ratio=0.5, n_features=10, combined_sampling=True)
# experiment_feature_count_effect_comb(x, y, n_trees=10, sample_ratio=0.5, max_depth=10)
# experiment_tree_count_effect_comb(x, y, sample_ratio=0.5, max_depth=10, n_features=10, combined_sampling=True)

# # Grid search
# sample_ratios = [0.3, 0.5, 0.7]
# tree_counts = [5, 10, 15]
# depths = [3,4,5,6,7,9, 10, None]
# n_features_list = [5, 10, 15]

# best_sample, best_trees, best_depth, best_features = grid_search_rf_comb(x, y, sample_ratios, tree_counts, depths, n_features_list)

# # Train final model with best params
# final_model = MyRandomForest_comb(n_trees=best_trees, sample_ratio=best_sample, max_depth=best_depth,
#                              n_features=best_features, combined_sampling=True)
# final_model.fit(x_train, y_train)
# final_preds = final_model.predict(x_test)
# print(" Final Accuracy:", accuracy_score(y_test, final_preds))

# %%
# # Final Configuration
# best_sample_ratio = 0.3
# best_n_trees = 100
# best_max_depth = None
# best_n_features = 10
# combined_sampling = True  # Since it's best with combined sampling

# # Instantiate and train the final model
# final_model = MyRandomForest_comb(
#     n_trees=best_n_trees,
#     sample_ratio=best_sample_ratio,
#     max_depth=best_max_depth,
#     n_features=best_n_features,
#     combined_sampling=combined_sampling
# )

# %%
# !pip install scapy
import csv
import os
from scapy.all import sniff, IP, TCP, UDP
from collections import defaultdict, deque
import time
import socket

# ======= File setup =======
csv_file_path = "/content/real_time_nids_features.csv"
csv_header = [
    "duration", "protocol_type", "service", "flag", "src_bytes", "dst_bytes", "land",
    "wrong_fragment", "urgent", "hot", "num_failed_logins", "logged_in", "num_compromised",
    "root_shell", "su_attempted", "num_root", "num_file_creations", "num_shells",
    "num_access_files", "num_outbound_cmds", "is_host_login", "is_guest_login",
    "count", "srv_count", "serror_rate", "srv_serror_rate", "rerror_rate",
    "srv_rerror_rate", "same_srv_rate", "diff_srv_rate", "srv_diff_host_rate",
    "dst_host_count", "dst_host_srv_count", "dst_host_same_srv_rate",
    "dst_host_diff_srv_rate", "dst_host_same_src_port_rate",
    "dst_host_srv_diff_host_rate", "dst_host_serror_rate",
    "dst_host_srv_serror_rate", "dst_host_rerror_rate",
    "dst_host_srv_rerror_rate"
]

# Write header only once
if not os.path.exists(csv_file_path):
    with open(csv_file_path, mode='w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(csv_header)

# ======= Flow tracking setup =======
flows = defaultdict(lambda: {
    'start_time': None,
    'end_time': None,
    'src_bytes': 0,
    'dst_bytes': 0,
    'count': 0,
    'services': set(),
    'dst_hosts': set(),
    'ports': set(),
    'tcp_flags': [],
    'logged_in': 0,
})

window = deque(maxlen=1000)
window_duration = 2  # seconds

def map_port_to_service(port):
    common_ports = {
        20: 'ftp_data',
        21: 'ftp',
        22: 'ssh',
        23: 'telnet',
        25: 'smtp',
        53: 'domain',
        69: 'tftp_u',
        80: 'http',
        110: 'pop_3',
        111: 'sunrpc',
        119: 'nntp',
        123: 'ntp_u',
        135: 'epmap',
        137: 'netbios_ns',
        138: 'netbios_dgm',
        139: 'netbios_ssn',
        143: 'imap4',
        161: 'snmp',
        162: 'snmptrap',
        179: 'bgp',
        443: 'https',
        445: 'microsoft_ds',
        513: 'login',
        514: 'shell',
        515: 'printer',
        520: 'route',
        540: 'uucp',
        635: 'mountd',
        8080: 'http',
    }

    if port in common_ports:
        return common_ports[port]
    elif port >= 1024:
        return 'private'
    else:
        return 'other'

def get_service(port):
    try:
        return socket.getservbyport(port)
    except OSError:
        return str(port)

def map_flags_to_dataset(flag):
    if flag in ['PA', 'A', 'P', 'FA', 'F']:
        return 'SF'
    elif flag == 'S':
        return 'S0'
    elif flag in ['R', 'RA']:
        return 'REJ'
    else:
        return 'OTH'

def extract_features(pkt):
    if not IP in pkt:
        return

    ip = pkt[IP]
    proto = pkt.proto
    now = time.time()

    if TCP in pkt or UDP in pkt:
        sport = pkt.sport
        dport = pkt.dport
    else:
        sport = dport = 0

    key = (ip.src, ip.dst, sport, dport, proto)

    flow = flows[key]
    if flow['start_time'] is None:
        flow['start_time'] = now
    flow['end_time'] = now

    flow['count'] += 1
    size = len(pkt)

    if ip.src == key[0]:
        flow['src_bytes'] += size
    else:
        flow['dst_bytes'] += size

    flow['services'].add(map_port_to_service(dport))
    flow['dst_hosts'].add(ip.dst)
    flow['ports'].add(dport)

    if TCP in pkt:
        tcp = pkt[TCP]
        flow['tcp_flags'].append(tcp.flags)
        if tcp.flags == "S":
            flow['logged_in'] = 0
        if tcp.flags == "PA":
            flow['logged_in'] = 1

    window.append({
        'src': ip.src,
        'dst': ip.dst,
        'proto': proto,
        'service': map_port_to_service(dport),
        'timestamp': now
    })

    duration = flow['end_time'] - flow['start_time']
    protocol_type = {6: 'tcp', 17: 'udp', 1: 'icmp'}.get(proto, 'other')
    service = list(flow['services'])[0] if flow['services'] else '0'
    raw_flag = flow['tcp_flags'][-1] if flow['tcp_flags'] else '0'
    flag = map_flags_to_dataset(str(raw_flag))  # Normalize it
    src_bytes = flow['src_bytes']
    dst_bytes = flow['dst_bytes']
    land = 1 if ip.src == ip.dst and sport == dport else 0

    wrong_fragment = 0
    urgent = 0
    hot = 0
    num_failed_logins = 0
    logged_in = flow['logged_in']
    num_compromised = 0
    root_shell = 0
    su_attempted = 0
    num_root = 0
    num_file_creations = 0
    num_shells = 0
    num_access_files = 0
    num_outbound_cmds = 0
    is_host_login = 0
    is_guest_login = 0

    recent = [w for w in window if now - w['timestamp'] <= window_duration]
    count = len([w for w in recent if w['dst'] == ip.dst])
    srv_count = len([w for w in recent if w['dst'] == ip.dst and w['service'] == service])

    serror_rate = 0
    srv_serror_rate = 0
    rerror_rate = 0
    srv_rerror_rate = 0
    same_srv_rate = srv_count / count if count else 0
    diff_srv_rate = 1 - same_srv_rate
    srv_diff_host_rate = 0

    dst_host_count = count
    dst_host_srv_count = srv_count
    dst_host_same_srv_rate = same_srv_rate
    dst_host_diff_srv_rate = diff_srv_rate
    dst_host_same_src_port_rate = 0
    dst_host_srv_diff_host_rate = 0
    dst_host_serror_rate = 0
    dst_host_srv_serror_rate = 0
    dst_host_rerror_rate = 0
    dst_host_srv_rerror_rate = 0

    features = [
        duration, protocol_type, service, flag, src_bytes, dst_bytes, land,
        wrong_fragment, urgent, hot, num_failed_logins, logged_in, num_compromised,
        root_shell, su_attempted, num_root, num_file_creations, num_shells,
        num_access_files, num_outbound_cmds, is_host_login, is_guest_login,
        count, srv_count, serror_rate, srv_serror_rate, rerror_rate,
        srv_rerror_rate, same_srv_rate, diff_srv_rate, srv_diff_host_rate,
        dst_host_count, dst_host_srv_count, dst_host_same_srv_rate,
        dst_host_diff_srv_rate, dst_host_same_src_port_rate,
        dst_host_srv_diff_host_rate, dst_host_serror_rate,
        dst_host_srv_serror_rate, dst_host_rerror_rate,
        dst_host_srv_rerror_rate
    ]

    # Save row to CSV
    with open(csv_file_path, mode='a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(features)

    print("Captured:", features[:5], "...")  # Print a summary

def start_sniffing(iface="eth0"):
    print("[*] Capturing packets & writing to:", csv_file_path)
    sniff(iface=iface, prn=extract_features, store=0)

if __name__ == "__main__":
    start_sniffing("eth0")  # Or "wlan0" or your actual Colab interface
# Out:
# Requirement already satisfied: scapy in /usr/local/lib/python3.11/dist-packages (2.6.1)
# [*] Capturing packets & writing to: /content/real_time_nids_features.csv
# Captured: [0.0, 'tcp', 'private', 'SF', 66] ...
# Captured: [0.0, 'tcp', 'private', 'SF', 66] ...
# Captured: [0.0, 'tcp', 'private', 'SF', 857] ...
# Captured: [0.0, 'tcp', 'http', 'SF', 66] ...
# Captured: [0.20415735244750977, 'tcp', 'private', 'SF', 1638] ...
# Captured: [0.2040727138519287, 'tcp', 'http', 'SF', 132] ...
# Captured: [0.0, 'tcp', 'private', 'SF', 875] ...
# Captured: [0.0, 'tcp', 'http', 'SF', 66] ...
# Captured: [0.40842175483703613, 'tcp', 'private', 'SF', 2548] ...
# Captured: [0.40843772888183594, 'tcp', 'http', 'SF', 198] ...
# Captured: [0.6122264862060547, 'tcp', 'private', 'SF', 3363] ...
# Captured: [0.6121249198913574, 'tcp', 'http', 'SF', 264] ...
# Captured: [0.815760612487793, 'tcp', 'private', 'SF', 4176] ...
# Captured: [0.8157386779785156, 'tcp', 'http', 'SF', 330] ...
# Captured: [0.6024410724639893, 'tcp', 'private', 'SF', 1749] ...
# Captured: [0.6029129028320312, 'tcp', 'http', 'SF', 132] ...
# Captured: [1.0201478004455566, 'tcp', 'private', 'SF', 5116] ...
# Captured: [1.0202279090881348, 'tcp', 'http', 'SF', 396] ...
# Captured: [1.224703073501587, 'tcp', 'private', 'SF', 5929] ...
# Captured: [1.2247364521026611, 'tcp', 'http', 'SF', 462] ...
# Captured: [1.429229974746704, 'tcp', 'private', 'SF', 6741] ...
# Captured: [1.4292502403259277, 'tcp', 'http', 'SF', 528] ...
# Captured: [1.2046124935150146, 'tcp', 'private', 'SF', 2621] ...
# Captured: [1.2048654556274414, 'tcp', 'http', 'SF', 198] ...
# Captured: [1.6337976455688477, 'tcp', 'private', 'SF', 7681] ...
# Captured: [1.6339600086212158, 'tcp', 'http', 'SF', 594] ...
# Captured: [1.8376116752624512, 'tcp', 'private', 'SF', 8494] ...
# Captured: [1.837545394897461, 'tcp', 'http', 'SF', 660] ...
# Captured: [2.0414209365844727, 'tcp', 'private', 'SF', 9306] ...
# Captured: [2.041301727294922, 'tcp', 'http', 'SF', 726] ...
# Captured: [1.8057007789611816, 'tcp', 'private', 'SF', 3495] ...
# Captured: [1.8055105209350586, 'tcp', 'http', 'SF', 264] ...
# Captured: [2.245518207550049, 'tcp', 'private', 'SF', 10246] ...
# Captured: [2.2456138134002686, 'tcp', 'http', 'SF', 792] ...
# Captured: [2.4494526386260986, 'tcp', 'private', 'SF', 11059] ...
# Captured: [2.4492363929748535, 'tcp', 'http', 'SF', 858] ...
# Captured: [2.6531105041503906, 'tcp', 'private', 'SF', 11873] ...
# Captured: [2.6530449390411377, 'tcp', 'http', 'SF', 924] ...
# Captured: [2.4077060222625732, 'tcp', 'private', 'SF', 4370] ...
# Captured: [2.4075255393981934, 'tcp', 'http', 'SF', 330] ...
# Captured: [2.8569693565368652, 'tcp', 'private', 'SF', 12815] ...
# Captured: [2.8569693565368652, 'tcp', 'http', 'SF', 990] ...
# Captured: [3.0607666969299316, 'tcp', 'private', 'SF', 13629] ...
# Captured: [3.0606143474578857, 'tcp', 'http', 'SF', 1056] ...
# Captured: [0.0, 'tcp', 'http', 'SF', 81] ...
# Captured: [0.0, 'tcp', 'private', 'SF', 113] ...
# Captured: [0.006886959075927734, 'tcp', 'http', 'SF', 147] ...
# Captured: [3.2648794651031494, 'tcp', 'private', 'SF', 14604] ...
# Captured: [3.2647392749786377, 'tcp', 'http', 'SF', 1122] ...
# Captured: [3.0099732875823975, 'tcp', 'private', 'SF', 5244] ...
# Captured: [3.0098061561584473, 'tcp', 'http', 'SF', 396] ...
# Captured: [3.469442844390869, 'tcp', 'private', 'SF', 15547] ...
# Captured: [3.4693026542663574, 'tcp', 'http', 'SF', 1188] ...
# Captured: [0.0, 'tcp', 'http', 'S0', 74] ...
# Captured: [0.0, 'tcp', 'http', 'S0', 74] ...
# Captured: [0.0, 'tcp', 'private', 'OTH', 74] ...
# Captured: [0.0, 'tcp', 'private', 'OTH', 74] ...
# Captured: [0.0037348270416259766, 'tcp', 'http', 'SF', 140] ...
# Captured: [0.0060350894927978516, 'tcp', 'http', 'SF', 140] ...
# Captured: [0.005926609039306641, 'tcp', 'http', 'SF', 992] ...
# Captured: [0.005861043930053711, 'tcp', 'private', 'SF', 140] ...
# Captured: [0.010179996490478516, 'tcp', 'http', 'SF', 992] ...
# Captured: [0.007781267166137695, 'tcp', 'private', 'SF', 140] ...
# Captured: [0.01001882553100586, 'tcp', 'private', 'SF', 2401] ...
# Captured: [0.012382984161376953, 'tcp', 'http', 'SF', 1058] ...
# Captured: [0.011136293411254883, 'tcp', 'private', 'SF', 768] ...
# Captured: [0.015249252319335938, 'tcp', 'http', 'SF', 1058] ...
# Captured: [0.01357412338256836, 'tcp', 'private', 'SF', 2467] ...
# Captured: [0.013184547424316406, 'tcp', 'private', 'SF', 834] ...
# Captured: [0.0172579288482666, 'tcp', 'http', 'SF', 1124] ...
# Captured: [0.014501094818115234, 'tcp', 'private', 'SF', 900] ...
# Captured: [0.017338037490844727, 'tcp', 'http', 'SF', 1124] ...
# Captured: [0.01695990562438965, 'tcp', 'private', 'SF', 2533] ...
# Captured: [3.673582077026367, 'tcp', 'private', 'SF', 17605] ...
# Captured: [3.673466205596924, 'tcp', 'http', 'SF', 1254] ...
# Captured: [3.6119027137756348, 'tcp', 'private', 'SF', 6116] ...
# Captured: [3.612896203994751, 'tcp', 'http', 'SF', 462] ...
# Captured: [3.878007650375366, 'tcp', 'private', 'SF', 18418] ...
# Captured: [3.8777921199798584, 'tcp', 'http', 'SF', 1320] ...
# Captured: [4.078979015350342, 'tcp', 'private', 'SF', 19359] ...
# Captured: [4.079298496246338, 'tcp', 'http', 'SF', 1386] ...
# Captured: [4.283233880996704, 'tcp', 'private', 'SF', 20172] ...
# Captured: [4.283202886581421, 'tcp', 'http', 'SF', 1452] ...
# Captured: [4.212849855422974, 'tcp', 'private', 'SF', 6987] ...
# Captured: [4.212759256362915, 'tcp', 'http', 'SF', 528] ...
# Captured: [4.487093448638916, 'tcp', 'private', 'SF', 21111] ...
# Captured: [4.48707914352417, 'tcp', 'http', 'SF', 1518] ...
# Captured: [4.691023111343384, 'tcp', 'private', 'SF', 21923] ...
# Captured: [4.69119119644165, 'tcp', 'http', 'SF', 1584] ...
# Captured: [4.895401954650879, 'tcp', 'private', 'SF', 22735] ...
# Captured: [4.895328998565674, 'tcp', 'http', 'SF', 1650] ...
# Captured: [4.815255403518677, 'tcp', 'private', 'SF', 7839] ...
# Captured: [4.815252780914307, 'tcp', 'http', 'SF', 594] ...
# Captured: [5.099706411361694, 'tcp', 'private', 'SF', 23674] ...
# Captured: [5.099649906158447, 'tcp', 'http', 'SF', 1716] ...
# Captured: [5.303682565689087, 'tcp', 'private', 'SF', 24487] ...
# Captured: [5.3036949634552, 'tcp', 'http', 'SF', 1782] ...
# Captured: [5.507838487625122, 'tcp', 'private', 'SF', 25298] ...
# Captured: [5.507773399353027, 'tcp', 'http', 'SF', 1848] ...
# Captured: [5.71306300163269, 'tcp', 'private', 'SF', 26111] ...
# Captured: [5.713003635406494, 'tcp', 'http', 'SF', 1914] ...
# Captured: [5.745818376541138, 'tcp', 'http', 'SF', 2345] ...
# Captured: [5.7486488819122314, 'tcp', 'private', 'SF', 26177] ...
# Captured: [5.917271375656128, 'tcp', 'private', 'SF', 27118] ...
# Captured: [5.956357717514038, 'tcp', 'http', 'SF', 2411] ...
# Captured: [6.121375322341919, 'tcp', 'private', 'SF', 27931] ...
# Captured: [6.1215598583221436, 'tcp', 'http', 'SF', 2477] ...
# Captured: [3.120457649230957, 'tcp', 'http', 'SF', 230] ...
# Captured: [3.119295835494995, 'tcp', 'private', 'SF', 226] ...
# Captured: [3.1258976459503174, 'tcp', 'http', 'SF', 296] ...
# Captured: [6.325550317764282, 'tcp', 'private', 'SF', 28932] ...
# Captured: [6.325421094894409, 'tcp', 'http', 'SF', 2543] ...
# Captured: [6.529662370681763, 'tcp', 'private', 'SF', 29745] ...
# Captured: [6.529472351074219, 'tcp', 'http', 'SF', 2609] ...
# Captured: [6.734155893325806, 'tcp', 'private', 'SF', 30558] ...
# Captured: [6.734297275543213, 'tcp', 'http', 'SF', 2675] ...
# Captured: [6.938405275344849, 'tcp', 'private', 'SF', 31371] ...
# Captured: [6.9383299350738525, 'tcp', 'http', 'SF', 2741] ...
# Captured: [7.142332553863525, 'tcp', 'private', 'SF', 32185] ...
# Captured: [7.142152309417725, 'tcp', 'http', 'SF', 2807] ...
# Captured: [7.346356391906738, 'tcp', 'private', 'SF', 32998] ...
# Captured: [7.346155166625977, 'tcp', 'http', 'SF', 2873] ...
# Captured: [7.5502612590789795, 'tcp', 'private', 'SF', 33811] ...
# Captured: [7.5500428676605225, 'tcp', 'http', 'SF', 2939] ...
# Captured: [7.754239320755005, 'tcp', 'private', 'SF', 34626] ...
# Captured: [7.754002809524536, 'tcp', 'http', 'SF', 3005] ...
# Captured: [7.95833158493042, 'tcp', 'private', 'SF', 35439] ...
# Captured: [7.958493232727051, 'tcp', 'http', 'SF', 3071] ...
# Captured: [8.163715839385986, 'tcp', 'private', 'SF', 36251] ...
# Captured: [8.163406133651733, 'tcp', 'http', 'SF', 3137] ...
# Captured: [8.368321895599365, 'tcp', 'private', 'SF', 37064] ...
# Captured: [8.368202686309814, 'tcp', 'http', 'SF', 3203] ...
# Captured: [8.57254934310913, 'tcp', 'private', 'SF', 37877] ...
# Captured: [8.57231879234314, 'tcp', 'http', 'SF', 3269] ...
# Captured: [8.77672529220581, 'tcp', 'private', 'SF', 38688] ...
# Captured: [8.776777029037476, 'tcp', 'http', 'SF', 3335] ...
# Captured: [5.73691987991333, 'tcp', 'http', 'SF', 379] ...
# Captured: [5.735149621963501, 'tcp', 'private', 'SF', 339] ...
# Captured: [5.741678714752197, 'tcp', 'http', 'SF', 445] ...
# Captured: [8.981124877929688, 'tcp', 'private', 'SF', 39685] ...
# Captured: [8.981025695800781, 'tcp', 'http', 'SF', 3401] ...
# Captured: [9.184938430786133, 'tcp', 'private', 'SF', 40498] ...
# Captured: [9.185094356536865, 'tcp', 'http', 'SF', 3467] ...
# Captured: [9.389204263687134, 'tcp', 'private', 'SF', 41311] ...
# Captured: [9.389017343521118, 'tcp', 'http', 'SF', 3533] ...
# Captured: [9.593204021453857, 'tcp', 'private', 'SF', 42124] ...
# Captured: [9.59298849105835, 'tcp', 'http', 'SF', 3599] ...
# Captured: [9.797387599945068, 'tcp', 'private', 'SF', 42936] ...
# Captured: [9.797218322753906, 'tcp', 'http', 'SF', 3665] ...
# Captured: [10.001398801803589, 'tcp', 'private', 'SF', 43749] ...
# Captured: [10.001176595687866, 'tcp', 'http', 'SF', 3731] ...
# Captured: [10.206413745880127, 'tcp', 'private', 'SF', 44564] ...
# Captured: [10.206243753433228, 'tcp', 'http', 'SF', 3797] ...
# Captured: [10.410528182983398, 'tcp', 'private', 'SF', 45379] ...
# Captured: [10.410290241241455, 'tcp', 'http', 'SF', 3863] ...
# Captured: [10.614415407180786, 'tcp', 'private', 'SF', 46194] ...
# Captured: [10.614766597747803, 'tcp', 'http', 'SF', 3929] ...
# Captured: [10.81879997253418, 'tcp', 'private', 'SF', 47009] ...
# Captured: [10.818747520446777, 'tcp', 'http', 'SF', 3995] ...
# Captured: [11.022989273071289, 'tcp', 'private', 'SF', 47823] ...
# Captured: [11.023082494735718, 'tcp', 'http', 'SF', 4061] ...
# Captured: [11.22709035873413, 'tcp', 'private', 'SF', 48638] ...
# Captured: [11.22687554359436, 'tcp', 'http', 'SF', 4127] ...
# Captured: [11.431915044784546, 'tcp', 'private', 'SF', 49451] ...
# Captured: [11.431835174560547, 'tcp', 'http', 'SF', 4193] ...
# Captured: [11.636013269424438, 'tcp', 'private', 'SF', 50266] ...
# Captured: [11.635845422744751, 'tcp', 'http', 'SF', 4259] ...
# Captured: [11.84006667137146, 'tcp', 'private', 'SF', 51081] ...
# Captured: [11.839827537536621, 'tcp', 'http', 'SF', 4325] ...
# Captured: [12.045560359954834, 'tcp', 'private', 'SF', 51895] ...
# Captured: [12.045505285263062, 'tcp', 'http', 'SF', 4391] ...
# Captured: [12.251623153686523, 'tcp', 'private', 'SF', 52710] ...
# Captured: [12.251917600631714, 'tcp', 'http', 'SF', 4457] ...
# Captured: [12.4556565284729, 'tcp', 'private', 'SF', 53525] ...
# Captured: [12.456203699111938, 'tcp', 'http', 'SF', 4523] ...
# Captured: [12.66014289855957, 'tcp', 'private', 'SF', 54338] ...
# Captured: [12.660239696502686, 'tcp', 'http', 'SF', 4589] ...
# Captured: [12.863962411880493, 'tcp', 'private', 'SF', 55152] ...
# Captured: [12.864119291305542, 'tcp', 'http', 'SF', 4655] ...
# Captured: [9.752012252807617, 'tcp', 'http', 'SF', 537] ...
# Captured: [9.748886346817017, 'tcp', 'private', 'SF', 454] ...
# Captured: [9.75579047203064, 'tcp', 'http', 'SF', 603] ...
# Captured: [9.89367389678955, 'tcp', 'http', 'SF', 686] ...
# Captured: [9.927810192108154, 'tcp', 'private', 'SF', 520] ...
# Captured: [13.06880259513855, 'tcp', 'private', 'SF', 56212] ...
# Captured: [13.06862187385559, 'tcp', 'http', 'SF', 4721] ...
# Captured: [10.107114315032959, 'tcp', 'http', 'SF', 772] ...
# Captured: [10.102750778198242, 'tcp', 'private', 'SF', 586] ...
# Captured: [10.107546329498291, 'tcp', 'private', 'SF', 701] ...
# Captured: [10.114591836929321, 'tcp', 'http', 'SF', 838] ...
# Captured: [13.269870519638062, 'tcp', 'private', 'SF', 57343] ...
# Captured: [13.270182847976685, 'tcp', 'http', 'SF', 4787] ...
# Captured: [10.28117561340332, 'tcp', 'http', 'SF', 918] ...
# Captured: [10.31568455696106, 'tcp', 'private', 'SF', 767] ...
# Captured: [13.474220752716064, 'tcp', 'private', 'SF', 58283] ...
# Captured: [13.474055290222168, 'tcp', 'http', 'SF', 4853] ...
# Captured: [10.432227611541748, 'tcp', 'http', 'SF', 1004] ...
# Captured: [10.428262710571289, 'tcp', 'private', 'SF', 833] ...
# Captured: [10.429314851760864, 'tcp', 'private', 'SF', 948] ...
# Captured: [10.435742139816284, 'tcp', 'http', 'SF', 1070] ...
# Captured: [13.678664445877075, 'tcp', 'private', 'SF', 59354] ...
# Captured: [13.678775310516357, 'tcp', 'http', 'SF', 4919] ...
# Captured: [10.579192876815796, 'tcp', 'http', 'SF', 1150] ...
# Captured: [10.61376404762268, 'tcp', 'private', 'SF', 1014] ...
# Captured: [0.0, 'tcp', 'http', 'S0', 74] ...
# Captured: [0.0, 'tcp', 'private', 'OTH', 74] ...
# Captured: [0.0026292800903320312, 'tcp', 'http', 'SF', 140] ...
# Captured: [0.004790782928466797, 'tcp', 'http', 'SF', 993] ...
# Captured: [0.0070154666900634766, 'tcp', 'private', 'SF', 140] ...
# Captured: [0.0, 'tcp', 'http', 'S0', 74] ...
# Captured: [0.0, 'tcp', 'private', 'OTH', 74] ...
# Captured: [0.002624034881591797, 'tcp', 'http', 'SF', 140] ...
# Captured: [0.006325483322143555, 'tcp', 'http', 'SF', 992] ...
# Captured: [0.006438255310058594, 'tcp', 'private', 'SF', 140] ...
# Captured: [0.01756000518798828, 'tcp', 'private', 'SF', 2401] ...
# Captured: [0.019754409790039062, 'tcp', 'http', 'SF', 1059] ...
# Captured: [0.02049851417541504, 'tcp', 'http', 'SF', 1125] ...
# Captured: [13.897507429122925, 'tcp', 'private', 'SF', 60458] ...
# Captured: [13.896857738494873, 'tcp', 'http', 'SF', 4985] ...
# Captured: [0.021271467208862305, 'tcp', 'private', 'SF', 2467] ...
# Captured: [0.023564815521240234, 'tcp', 'http', 'SF', 1191] ...
# Captured: [0.013204813003540039, 'tcp', 'private', 'SF', 768] ...
# Captured: [0.015265464782714844, 'tcp', 'http', 'SF', 1058] ...
# Captured: [0.016099214553833008, 'tcp', 'http', 'SF', 1124] ...
# Captured: [0.015824556350708008, 'tcp', 'private', 'SF', 834] ...
# Captured: [0.018143892288208008, 'tcp', 'http', 'SF', 1190] ...
# Captured: [10.828696012496948, 'tcp', 'http', 'SF', 1241] ...
# Captured: [10.824777126312256, 'tcp', 'private', 'SF', 1080] ...
# Captured: [10.82725214958191, 'tcp', 'private', 'SF', 1193] ...
# Captured: [10.83435583114624, 'tcp', 'http', 'SF', 1307] ...
# Captured: [14.08701229095459, 'tcp', 'private', 'SF', 62610] ...
# Captured: [14.087174892425537, 'tcp', 'http', 'SF', 5051] ...
# Captured: [14.291459321975708, 'tcp', 'private', 'SF', 63424] ...
# Captured: [14.291428089141846, 'tcp', 'http', 'SF', 5117] ...
# Captured: [11.252652645111084, 'tcp', 'http', 'SF', 1404] ...
# Captured: [11.286736249923706, 'tcp', 'private', 'SF', 1259] ...
# Captured: [14.496003150939941, 'tcp', 'private', 'SF', 64368] ...
# Captured: [14.497225522994995, 'tcp', 'http', 'SF', 5183] ...
# Captured: [11.368993520736694, 'tcp', 'http', 'SF', 1493] ...
# Captured: [11.364603996276855, 'tcp', 'private', 'SF', 1325] ...
# Captured: [11.517367601394653, 'tcp', 'http', 'SF', 1584] ...
# Captured: [11.513426065444946, 'tcp', 'private', 'SF', 1391] ...
# Captured: [14.701756954193115, 'tcp', 'private', 'SF', 65441] ...
# Captured: [14.702137470245361, 'tcp', 'http', 'SF', 5249] ...
# Captured: [14.846806049346924, 'tcp', 'private', 'SF', 132] ...
# Captured: [14.848778486251831, 'tcp', 'private', 'SF', 132] ...
# Captured: [11.699254274368286, 'tcp', 'http', 'SF', 1674] ...
# Captured: [11.695380687713623, 'tcp', 'private', 'SF', 1457] ...
# Captured: [11.739025592803955, 'tcp', 'http', 'SF', 1764] ...
# Captured: [11.735011339187622, 'tcp', 'private', 'SF', 1523] ...
# Captured: [14.9071786403656, 'tcp', 'private', 'SF', 66644] ...
# Captured: [14.90725326538086, 'tcp', 'http', 'SF', 5315] ...
# Captured: [14.948488235473633, 'tcp', 'private', 'SF', 305] ...
# Captured: [14.951635122299194, 'tcp', 'private', 'SF', 4294] ...
# Captured: [14.952505588531494, 'tcp', 'private', 'SF', 371] ...
# Captured: [14.957223653793335, 'tcp', 'private', 'SF', 6518] ...
# Captured: [14.958043813705444, 'tcp', 'private', 'SF', 437] ...
# Captured: [0.0, 'tcp', 'http', 'S0', 74] ...
# Captured: [0.0, 'tcp', 'private', 'OTH', 74] ...
# Captured: [0.0033233165740966797, 'tcp', 'http', 'SF', 140] ...
# Captured: [0.004885435104370117, 'tcp', 'http', 'SF', 324] ...
# Captured: [0.0048449039459228516, 'tcp', 'private', 'SF', 140] ...
# Captured: [0.0065233707427978516, 'tcp', 'private', 'SF', 3246] ...
# Captured: [0.013828277587890625, 'tcp', 'http', 'SF', 390] ...
# Captured: [0.013946056365966797, 'tcp', 'private', 'SF', 3317] ...
# Captured: [0.017458200454711914, 'tcp', 'http', 'SF', 456] ...
# Captured: [0.0211641788482666, 'tcp', 'http', 'SF', 522] ...
# Captured: [0.021045684814453125, 'tcp', 'private', 'SF', 3383] ...
# Captured: [0.024898529052734375, 'tcp', 'http', 'SF', 588] ...
# Captured: [15.111639738082886, 'tcp', 'private', 'SF', 68535] ...
# Captured: [15.111934661865234, 'tcp', 'http', 'SF', 5381] ...
# Captured: [12.007401943206787, 'tcp', 'http', 'SF', 1850] ...
# Captured: [12.004314661026001, 'tcp', 'private', 'SF', 1589] ...
# Captured: [12.009851694107056, 'tcp', 'private', 'SF', 1702] ...
# Captured: [12.01863408088684, 'tcp', 'http', 'SF', 1916] ...
# Captured: [15.318127393722534, 'tcp', 'private', 'SF', 69607] ...
# Captured: [15.318609476089478, 'tcp', 'http', 'SF', 5447] ...
# Captured: [15.525564193725586, 'tcp', 'private', 'SF', 70422] ...
# Captured: [15.526407718658447, 'tcp', 'http', 'SF', 5513] ...
# Captured: [12.519506692886353, 'tcp', 'private', 'SF', 2118] ...
# Captured: [12.526411533355713, 'tcp', 'http', 'SF', 1982] ...
# Captured: [15.73065996170044, 'tcp', 'private', 'SF', 71366] ...
# Captured: [15.73100757598877, 'tcp', 'http', 'SF', 5579] ...
# Captured: [15.935389041900635, 'tcp', 'private', 'SF', 72179] ...
# Captured: [15.935439825057983, 'tcp', 'http', 'SF', 5645] ...
# Captured: [16.139631748199463, 'tcp', 'private', 'SF', 72994] ...
# Captured: [16.139841556549072, 'tcp', 'http', 'SF', 5711] ...
# Captured: [13.100269079208374, 'tcp', 'http', 'SF', 2065] ...
# Captured: [13.102069854736328, 'tcp', 'http', 'SF', 2148] ...
# Captured: [13.099164009094238, 'tcp', 'private', 'SF', 2184] ...
# Captured: [13.101516962051392, 'tcp', 'private', 'SF', 2297] ...
# Captured: [13.108619451522827, 'tcp', 'http', 'SF', 2214] ...
# Captured: [13.103880882263184, 'tcp', 'private', 'SF', 2410] ...
# Captured: [13.110423803329468, 'tcp', 'http', 'SF', 2280] ...
# Captured: [16.344205617904663, 'tcp', 'private', 'SF', 74259] ...
# Captured: [16.344008207321167, 'tcp', 'http', 'SF', 5777] ...
# Captured: [16.549381017684937, 'tcp', 'private', 'SF', 75074] ...
# Captured: [16.54937195777893, 'tcp', 'http', 'SF', 5843] ...
# Captured: [16.593958377838135, 'tcp', 'http', 'SF', 6438] ...
# Captured: [16.596636533737183, 'tcp', 'private', 'SF', 75140] ...
# Captured: [16.753509283065796, 'tcp', 'private', 'SF', 76084] ...
# Captured: [16.753495693206787, 'tcp', 'http', 'SF', 6504] ...
# Captured: [16.957731008529663, 'tcp', 'private', 'SF', 76899] ...
# Captured: [16.958011388778687, 'tcp', 'http', 'SF', 6570] ...
# Captured: [17.16208291053772, 'tcp', 'private', 'SF', 77714] ...
# Captured: [17.16236424446106, 'tcp', 'http', 'SF', 6636] ...
# Captured: [17.36669135093689, 'tcp', 'private', 'SF', 78527] ...
# Captured: [17.3669331073761, 'tcp', 'http', 'SF', 6702] ...
# Captured: [17.572304248809814, 'tcp', 'private', 'SF', 79339] ...
# Captured: [17.572263479232788, 'tcp', 'http', 'SF', 6768] ...
# Captured: [17.77671480178833, 'tcp', 'private', 'SF', 80154] ...
# Captured: [17.77674627304077, 'tcp', 'http', 'SF', 6834] ...
# Captured: [17.981088638305664, 'tcp', 'private', 'SF', 80967] ...
# Captured: [17.98107099533081, 'tcp', 'http', 'SF', 6900] ...
# Captured: [18.185014486312866, 'tcp', 'private', 'SF', 81781] ...
# Captured: [18.185006141662598, 'tcp', 'http', 'SF', 6966] ...
# Captured: [18.390490531921387, 'tcp', 'private', 'SF', 82596] ...
# Captured: [18.39033603668213, 'tcp', 'http', 'SF', 7032] ...
# Captured: [18.595383405685425, 'tcp', 'private', 'SF', 83410] ...
# Captured: [18.59544324874878, 'tcp', 'http', 'SF', 7098] ...
# Captured: [18.799811601638794, 'tcp', 'private', 'SF', 84224] ...
# Captured: [18.799442052841187, 'tcp', 'http', 'SF', 7164] ...
# Captured: [19.004799365997314, 'tcp', 'private', 'SF', 85039] ...
# Captured: [19.00487208366394, 'tcp', 'http', 'SF', 7230] ...
# Captured: [19.09617519378662, 'tcp', 'http', 'SF', 8086] ...
# Captured: [19.098920106887817, 'tcp', 'private', 'SF', 85105] ...
# Captured: [19.210336685180664, 'tcp', 'private', 'SF', 86048] ...
# Captured: [19.21021342277527, 'tcp', 'http', 'SF', 8152] ...
# Captured: [19.414628982543945, 'tcp', 'private', 'SF', 86862] ...
# Captured: [19.414520740509033, 'tcp', 'http', 'SF', 8218] ...
# Captured: [19.618909120559692, 'tcp', 'private', 'SF', 87677] ...
# Captured: [19.618828058242798, 'tcp', 'http', 'SF', 8284] ...
# Captured: [19.82317876815796, 'tcp', 'private', 'SF', 88492] ...
# Captured: [19.82286548614502, 'tcp', 'http', 'SF', 8350] ...
# Captured: [20.029464721679688, 'tcp', 'private', 'SF', 89305] ...
# Captured: [20.029372215270996, 'tcp', 'http', 'SF', 8416] ...
# Captured: [20.234785795211792, 'tcp', 'private', 'SF', 90120] ...
# Captured: [20.234961986541748, 'tcp', 'http', 'SF', 8482] ...
# Captured: [20.439486503601074, 'tcp', 'private', 'SF', 90935] ...
# Captured: [20.439318656921387, 'tcp', 'http', 'SF', 8548] ...
# Captured: [20.64371657371521, 'tcp', 'private', 'SF', 91750] ...
# Captured: [20.64362645149231, 'tcp', 'http', 'SF', 8614] ...
# Captured: [20.84776759147644, 'tcp', 'private', 'SF', 92563] ...
# Captured: [20.848018169403076, 'tcp', 'http', 'SF', 8680] ...
# Captured: [21.052297830581665, 'tcp', 'private', 'SF', 93377] ...
# Captured: [21.052146911621094, 'tcp', 'http', 'SF', 8746] ...
# Captured: [21.25648045539856, 'tcp', 'private', 'SF', 94192] ...
# Captured: [21.25645112991333, 'tcp', 'http', 'SF', 8812] ...
# Captured: [21.46082067489624, 'tcp', 'private', 'SF', 95005] ...
# Captured: [21.46091365814209, 'tcp', 'http', 'SF', 8878] ...
# Captured: [21.66517400741577, 'tcp', 'private', 'SF', 95818] ...
# Captured: [21.66477870941162, 'tcp', 'http', 'SF', 8944] ...
# Captured: [21.870129108428955, 'tcp', 'private', 'SF', 96631] ...
# Captured: [21.87002730369568, 'tcp', 'http', 'SF', 9010] ...
# Captured: [22.074254989624023, 'tcp', 'private', 'SF', 97445] ...
# Captured: [22.07448673248291, 'tcp', 'http', 'SF', 9076] ...
# Captured: [22.27876329421997, 'tcp', 'private', 'SF', 98259] ...
# Captured: [22.278809309005737, 'tcp', 'http', 'SF', 9142] ...
# Captured: [22.4841525554657, 'tcp', 'private', 'SF', 99073] ...
# Captured: [22.483829021453857, 'tcp', 'http', 'SF', 9208] ...
# Captured: [22.68985152244568, 'tcp', 'private', 'SF', 99886] ...
# Captured: [22.69041395187378, 'tcp', 'http', 'SF', 9274] ...
# Captured: [22.894553899765015, 'tcp', 'private', 'SF', 100699] ...
# Captured: [22.894426822662354, 'tcp', 'http', 'SF', 9340] ...
# Captured: [23.09860634803772, 'tcp', 'private', 'SF', 101515] ...
# Captured: [23.098520040512085, 'tcp', 'http', 'SF', 9406] ...
# Captured: [23.30289626121521, 'tcp', 'private', 'SF', 102330] ...
# Captured: [23.303022146224976, 'tcp', 'http', 'SF', 9472] ...
# Captured: [23.508925914764404, 'tcp', 'private', 'SF', 103145] ...
# Captured: [23.509129762649536, 'tcp', 'http', 'SF', 9538] ...
# Captured: [23.715126991271973, 'tcp', 'private', 'SF', 103961] ...
# Captured: [23.715280055999756, 'tcp', 'http', 'SF', 9604] ...
# Captured: [23.919496059417725, 'tcp', 'private', 'SF', 104777] ...
# Captured: [23.91974401473999, 'tcp', 'http', 'SF', 9670] ...
# Captured: [24.1252281665802, 'tcp', 'private', 'SF', 105592] ...
# Captured: [24.12537908554077, 'tcp', 'http', 'SF', 9736] ...
# Captured: [0.0, 'tcp', 'http', 'S0', 74] ...
# Captured: [0.0, 'tcp', 'private', 'OTH', 74] ...
# Captured: [0.002263307571411133, 'tcp', 'http', 'SF', 140] ...
# Captured: [0.0, 'tcp', 'http', 'S0', 74] ...
# Captured: [0.0, 'tcp', 'private', 'OTH', 74] ...
# Captured: [0.001905202865600586, 'tcp', 'http', 'SF', 140] ...
# Captured: [0.003651857376098633, 'tcp', 'http', 'SF', 993] ...
# Captured: [0.0036628246307373047, 'tcp', 'private', 'SF', 140] ...
# Captured: [0.012156248092651367, 'tcp', 'private', 'SF', 2401] ...
# Captured: [0.014589548110961914, 'tcp', 'private', 'SF', 2467] ...
# Captured: [0.0175933837890625, 'tcp', 'http', 'SF', 1059] ...
# Captured: [0.019484281539916992, 'tcp', 'http', 'SF', 1125] ...
# Captured: [0.019669532775878906, 'tcp', 'private', 'SF', 2533] ...
# Captured: [0.027486801147460938, 'tcp', 'http', 'SF', 992] ...
# Captured: [0.027373790740966797, 'tcp', 'private', 'SF', 140] ...
# Captured: [24.339758157730103, 'tcp', 'private', 'SF', 106993] ...
# Captured: [24.3396999835968, 'tcp', 'http', 'SF', 9802] ...
# Captured: [0.039171695709228516, 'tcp', 'private', 'SF', 768] ...
# Captured: [0.04172563552856445, 'tcp', 'http', 'SF', 1058] ...
# Captured: [0.043112754821777344, 'tcp', 'http', 'SF', 1124] ...
# Captured: [0.04488086700439453, 'tcp', 'private', 'SF', 834] ...
# Captured: [0.04732561111450195, 'tcp', 'http', 'SF', 1190] ...
# Captured: [24.53274130821228, 'tcp', 'private', 'SF', 108460] ...
# Captured: [24.53326964378357, 'tcp', 'http', 'SF', 9868] ...
# Captured: [24.73821473121643, 'tcp', 'private', 'SF', 109274] ...
# Captured: [24.73881220817566, 'tcp', 'http', 'SF', 9934] ...
# Captured: [24.944872617721558, 'tcp', 'private', 'SF', 110088] ...
# Captured: [24.945707321166992, 'tcp', 'http', 'SF', 10000] ...
# Captured: [25.1499183177948, 'tcp', 'private', 'SF', 110905] ...
# Captured: [25.149961948394775, 'tcp', 'http', 'SF', 10066] ...
# Captured: [25.354117155075073, 'tcp', 'private', 'SF', 111720] ...
# Captured: [25.354212999343872, 'tcp', 'http', 'SF', 10132] ...
# Captured: [25.559996843338013, 'tcp', 'private', 'SF', 112537] ...
# Captured: [25.5603346824646, 'tcp', 'http', 'SF', 10198] ...
# Captured: [25.764785766601562, 'tcp', 'private', 'SF', 113352] ...
# Captured: [25.764773845672607, 'tcp', 'http', 'SF', 10264] ...
# Captured: [25.968997478485107, 'tcp', 'private', 'SF', 114169] ...
# Captured: [25.96905755996704, 'tcp', 'http', 'SF', 10330] ...
# Captured: [26.175704956054688, 'tcp', 'private', 'SF', 114985] ...
# Captured: [26.17621684074402, 'tcp', 'http', 'SF', 10396] ...
# Captured: [26.380246877670288, 'tcp', 'private', 'SF', 115801] ...
# Captured: [26.38014531135559, 'tcp', 'http', 'SF', 10462] ...
# Captured: [26.584492921829224, 'tcp', 'private', 'SF', 116617] ...
# Captured: [26.5844304561615, 'tcp', 'http', 'SF', 10528] ...
# Captured: [26.78951096534729, 'tcp', 'private', 'SF', 117432] ...
# Captured: [26.789523601531982, 'tcp', 'http', 'SF', 10594] ...
# Captured: [26.993531942367554, 'tcp', 'private', 'SF', 118248] ...
# Captured: [26.993464708328247, 'tcp', 'http', 'SF', 10660] ...
# Captured: [27.199065685272217, 'tcp', 'private', 'SF', 119065] ...
# Captured: [27.199342012405396, 'tcp', 'http', 'SF', 10726] ...
# Captured: [27.403558015823364, 'tcp', 'private', 'SF', 119882] ...
# Captured: [27.40356707572937, 'tcp', 'http', 'SF', 10792] ...
# Captured: [27.607869148254395, 'tcp', 'private', 'SF', 120698] ...
# Captured: [27.607778310775757, 'tcp', 'http', 'SF', 10858] ...
# Captured: [27.812225103378296, 'tcp', 'private', 'SF', 121515] ...
# Captured: [27.812069177627563, 'tcp', 'http', 'SF', 10924] ...
# Captured: [28.01649522781372, 'tcp', 'private', 'SF', 122332] ...
# Captured: [28.016165018081665, 'tcp', 'http', 'SF', 10990] ...
# Captured: [28.22517967224121, 'tcp', 'private', 'SF', 123148] ...
# Captured: [28.22529172897339, 'tcp', 'http', 'SF', 11056] ...
# Captured: [28.431077480316162, 'tcp', 'private', 'SF', 123963] ...
# Captured: [28.43121647834778, 'tcp', 'http', 'SF', 11122] ...
# Captured: [28.635766983032227, 'tcp', 'private', 'SF', 124779] ...
# Captured: [28.635658025741577, 'tcp', 'http', 'SF', 11188] ...
# Captured: [28.840210437774658, 'tcp', 'private', 'SF', 125596] ...
# Captured: [28.840246200561523, 'tcp', 'http', 'SF', 11254] ...
# Captured: [29.045947313308716, 'tcp', 'private', 'SF', 126413] ...
# Captured: [29.045929193496704, 'tcp', 'http', 'SF', 11320] ...
# Captured: [29.252772569656372, 'tcp', 'private', 'SF', 127230] ...
# Captured: [29.252970218658447, 'tcp', 'http', 'SF', 11386] ...
# Captured: [29.45854663848877, 'tcp', 'private', 'SF', 128047] ...
# Captured: [29.45849871635437, 'tcp', 'http', 'SF', 11452] ...
# Captured: [29.662750720977783, 'tcp', 'private', 'SF', 128862] ...
# Captured: [29.662724256515503, 'tcp', 'http', 'SF', 11518] ...
# Captured: [29.867246866226196, 'tcp', 'private', 'SF', 129679] ...
# Captured: [29.86727261543274, 'tcp', 'http', 'SF', 11584] ...
# Captured: [30.073290824890137, 'tcp', 'private', 'SF', 130495] ...
# Captured: [30.073315858840942, 'tcp', 'http', 'SF', 11650] ...
# Captured: [30.20747971534729, 'tcp', 'private', 'SF', 6584] ...
# Captured: [30.207742929458618, 'tcp', 'private', 'SF', 503] ...
# Captured: [30.280804872512817, 'tcp', 'private', 'SF', 131442] ...
# Captured: [30.28117299079895, 'tcp', 'http', 'SF', 11716] ...
# Captured: [30.485203981399536, 'tcp', 'private', 'SF', 132258] ...
# Captured: [30.48535704612732, 'tcp', 'http', 'SF', 11782] ...
# Captured: [30.689406633377075, 'tcp', 'private', 'SF', 133074] ...
# Captured: [30.689311981201172, 'tcp', 'http', 'SF', 11848] ...
# Captured: [30.893824815750122, 'tcp', 'private', 'SF', 133891] ...
# Captured: [30.893754482269287, 'tcp', 'http', 'SF', 11914] ...
# Captured: [31.09832262992859, 'tcp', 'private', 'SF', 134708] ...
# Captured: [31.098171710968018, 'tcp', 'http', 'SF', 11980] ...
# Captured: [31.30724310874939, 'tcp', 'private', 'SF', 135524] ...
# Captured: [31.307400465011597, 'tcp', 'http', 'SF', 12046] ...
# Captured: [31.511728525161743, 'tcp', 'private', 'SF', 136340] ...
# Captured: [31.51192021369934, 'tcp', 'http', 'SF', 12112] ...
# Captured: [28.453015089035034, 'tcp', 'http', 'SF', 2361] ...
# Captured: [28.451361894607544, 'tcp', 'private', 'SF', 2523] ...
# Captured: [28.45810627937317, 'tcp', 'http', 'SF', 2427] ...
# Captured: [31.716375589370728, 'tcp', 'private', 'SF', 137347] ...
# Captured: [31.716354370117188, 'tcp', 'http', 'SF', 12178] ...
# Captured: [31.920878410339355, 'tcp', 'private', 'SF', 138164] ...
# Captured: [31.9209988117218, 'tcp', 'http', 'SF', 12244] ...
# Captured: [32.12523627281189, 'tcp', 'private', 'SF', 138979] ...
# Captured: [32.1251494884491, 'tcp', 'http', 'SF', 12310] ...
# Captured: [32.329384565353394, 'tcp', 'private', 'SF', 139793] ...
# Captured: [32.329275131225586, 'tcp', 'http', 'SF', 12376] ...
# Captured: [32.533493518829346, 'tcp', 'private', 'SF', 140610] ...
# Captured: [32.533469438552856, 'tcp', 'http', 'SF', 12442] ...
# Captured: [32.73782157897949, 'tcp', 'private', 'SF', 141427] ...
# Captured: [32.73781228065491, 'tcp', 'http', 'SF', 12508] ...
# Captured: [32.942238569259644, 'tcp', 'private', 'SF', 142242] ...
# Captured: [32.94280004501343, 'tcp', 'http', 'SF', 12574] ...
# Captured: [33.14716720581055, 'tcp', 'private', 'SF', 143058] ...
# Captured: [33.14692568778992, 'tcp', 'http', 'SF', 12640] ...
# Captured: [33.35212182998657, 'tcp', 'private', 'SF', 143873] ...
# Captured: [33.35205340385437, 'tcp', 'http', 'SF', 12706] ...
# Captured: [33.55651092529297, 'tcp', 'private', 'SF', 144688] ...
# Captured: [33.55655241012573, 'tcp', 'http', 'SF', 12772] ...
# Captured: [33.76196503639221, 'tcp', 'private', 'SF', 145503] ...
# Captured: [33.76214814186096, 'tcp', 'http', 'SF', 12838] ...
# Captured: [33.966753005981445, 'tcp', 'private', 'SF', 146318] ...
# Captured: [33.96646547317505, 'tcp', 'http', 'SF', 12904] ...
# Captured: [34.171874046325684, 'tcp', 'private', 'SF', 147134] ...
# Captured: [34.17186498641968, 'tcp', 'http', 'SF', 12970] ...
# Captured: [34.37597322463989, 'tcp', 'private', 'SF', 147950] ...
# Captured: [34.37588453292847, 'tcp', 'http', 'SF', 13036] ...
# Captured: [34.58032846450806, 'tcp', 'private', 'SF', 148765] ...
# Captured: [34.58020544052124, 'tcp', 'http', 'SF', 13102] ...
# Captured: [0.0, 'tcp', 'http', 'S0', 74] ...
# Captured: [0.0, 'tcp', 'private', 'OTH', 74] ...
# Captured: [0.002474546432495117, 'tcp', 'http', 'SF', 140] ...
# Captured: [0.003772735595703125, 'tcp', 'http', 'SF', 992] ...
# Captured: [0.003612518310546875, 'tcp', 'private', 'SF', 140] ...
# Captured: [0.0, 'tcp', 'http', 'S0', 74] ...
# Captured: [0.0, 'tcp', 'private', 'OTH', 74] ...
# Captured: [0.002081155776977539, 'tcp', 'http', 'SF', 140] ...
# Captured: [0.00823521614074707, 'tcp', 'private', 'SF', 2401] ...
# Captured: [0.010665178298950195, 'tcp', 'http', 'SF', 1058] ...
# Captured: [0.011792421340942383, 'tcp', 'http', 'SF', 1124] ...
# Captured: [0.011466503143310547, 'tcp', 'private', 'SF', 2467] ...
# Captured: [0.013884305953979492, 'tcp', 'http', 'SF', 1190] ...
# Captured: [0.00878143310546875, 'tcp', 'http', 'SF', 992] ...
# Captured: [0.008630037307739258, 'tcp', 'private', 'SF', 140] ...
# Captured: [0.00943303108215332, 'tcp', 'private', 'SF', 768] ...
# Captured: [0.011236906051635742, 'tcp', 'http', 'SF', 1058] ...
# Captured: [0.010983467102050781, 'tcp', 'private', 'SF', 834] ...
# Captured: [0.012782812118530273, 'tcp', 'http', 'SF', 1124] ...
# Captured: [0.012430191040039062, 'tcp', 'private', 'SF', 900] ...
# Captured: [34.78482460975647, 'tcp', 'private', 'SF', 150821] ...
# Captured: [34.78464150428772, 'tcp', 'http', 'SF', 13168] ...
# Captured: [34.9918909072876, 'tcp', 'private', 'SF', 151636] ...
# Captured: [34.99242115020752, 'tcp', 'http', 'SF', 13234] ...
# Captured: [35.19719099998474, 'tcp', 'private', 'SF', 152450] ...
# Captured: [35.19758105278015, 'tcp', 'http', 'SF', 13300] ...
# Captured: [35.031652212142944, 'tcp', 'http', 'SF', 660] ...
# Captured: [35.03424286842346, 'tcp', 'private', 'SF', 7905] ...
# Captured: [35.40415120124817, 'tcp', 'private', 'SF', 153392] ...
# Captured: [35.40455079078674, 'tcp', 'http', 'SF', 13366] ...
# Captured: [35.609628677368164, 'tcp', 'private', 'SF', 154207] ...
# Captured: [35.61015748977661, 'tcp', 'http', 'SF', 13432] ...
# Captured: [35.8164803981781, 'tcp', 'private', 'SF', 155023] ...
# Captured: [35.81699514389038, 'tcp', 'http', 'SF', 13498] ...
# Captured: [36.02293300628662, 'tcp', 'private', 'SF', 155837] ...
# Captured: [36.023399353027344, 'tcp', 'http', 'SF', 13564] ...
# Captured: [36.22828912734985, 'tcp', 'private', 'SF', 156653] ...
# Captured: [36.228824615478516, 'tcp', 'http', 'SF', 13630] ...
# Captured: [36.433276653289795, 'tcp', 'private', 'SF', 157469] ...
# Captured: [36.43388271331787, 'tcp', 'http', 'SF', 13696] ...
# Captured: [36.63825345039368, 'tcp', 'private', 'SF', 158285] ...
# Captured: [36.63871383666992, 'tcp', 'http', 'SF', 13762] ...
# Captured: [36.84298253059387, 'tcp', 'private', 'SF', 159100] ...
# Captured: [36.8429741859436, 'tcp', 'http', 'SF', 13828] ...
# Captured: [37.047383546829224, 'tcp', 'private', 'SF', 159914] ...
# Captured: [37.04734230041504, 'tcp', 'http', 'SF', 13894] ...
# Captured: [37.25173497200012, 'tcp', 'private', 'SF', 160730] ...
# Captured: [37.25179648399353, 'tcp', 'http', 'SF', 13960] ...
# Captured: [37.456013202667236, 'tcp', 'private', 'SF', 161545] ...
# Captured: [37.4561026096344, 'tcp', 'http', 'SF', 14026] ...
# Captured: [37.66058802604675, 'tcp', 'private', 'SF', 162360] ...
# Captured: [37.660529375076294, 'tcp', 'http', 'SF', 14092] ...
# Captured: [37.86513710021973, 'tcp', 'private', 'SF', 163176] ...
# Captured: [37.8654305934906, 'tcp', 'http', 'SF', 14158] ...
# Captured: [38.069703578948975, 'tcp', 'private', 'SF', 163990] ...
# Captured: [38.069647550582886, 'tcp', 'http', 'SF', 14224] ...
# Captured: [38.27422285079956, 'tcp', 'private', 'SF', 164807] ...
# Captured: [38.27399706840515, 'tcp', 'http', 'SF', 14290] ...
# Captured: [38.481228828430176, 'tcp', 'private', 'SF', 165622] ...
# Captured: [38.48137140274048, 'tcp', 'http', 'SF', 14356] ...
# Captured: [38.68581032752991, 'tcp', 'private', 'SF', 166438] ...
# Captured: [38.686139822006226, 'tcp', 'http', 'SF', 14422] ...
# Captured: [38.89061093330383, 'tcp', 'private', 'SF', 167254] ...
# Captured: [38.89037370681763, 'tcp', 'http', 'SF', 14488] ...
# Captured: [39.096139907836914, 'tcp', 'private', 'SF', 168069] ...
# Captured: [39.09608840942383, 'tcp', 'http', 'SF', 14554] ...
# Captured: [39.300544023513794, 'tcp', 'private', 'SF', 168885] ...
# Captured: [39.30050325393677, 'tcp', 'http', 'SF', 14620] ...
# Captured: [39.504979610443115, 'tcp', 'private', 'SF', 169701] ...
# Captured: [39.50486898422241, 'tcp', 'http', 'SF', 14686] ...
# Captured: [39.710774183273315, 'tcp', 'private', 'SF', 170517] ...
# Captured: [39.71074843406677, 'tcp', 'http', 'SF', 14752] ...
# Captured: [39.91546559333801, 'tcp', 'private', 'SF', 171333] ...
# Captured: [39.91554856300354, 'tcp', 'http', 'SF', 14818] ...
# Captured: [40.120001792907715, 'tcp', 'private', 'SF', 172148] ...
# Captured: [40.12000751495361, 'tcp', 'http', 'SF', 14884] ...
# Captured: [40.324482440948486, 'tcp', 'private', 'SF', 172964] ...
# Captured: [40.32448673248291, 'tcp', 'http', 'SF', 14950] ...
# Captured: [40.529969453811646, 'tcp', 'private', 'SF', 173780] ...
# Captured: [40.52970862388611, 'tcp', 'http', 'SF', 15016] ...
# Captured: [40.73660206794739, 'tcp', 'private', 'SF', 174596] ...
# Captured: [40.73673748970032, 'tcp', 'http', 'SF', 15082] ...
# Captured: [40.94176936149597, 'tcp', 'private', 'SF', 175411] ...
# Captured: [40.94187307357788, 'tcp', 'http', 'SF', 15148] ...
# Captured: [41.14638376235962, 'tcp', 'private', 'SF', 176226] ...
# Captured: [41.146390199661255, 'tcp', 'http', 'SF', 15214] ...
# Captured: [41.35088515281677, 'tcp', 'private', 'SF', 177042] ...
# Captured: [41.35091280937195, 'tcp', 'http', 'SF', 15280] ...
# Captured: [41.55540657043457, 'tcp', 'private', 'SF', 177857] ...
# Captured: [41.555381536483765, 'tcp', 'http', 'SF', 15346] ...
# Captured: [41.76035737991333, 'tcp', 'private', 'SF', 178673] ...
# Captured: [41.760053634643555, 'tcp', 'http', 'SF', 15412] ...
# Captured: [41.96606922149658, 'tcp', 'private', 'SF', 179489] ...
# Captured: [41.96614360809326, 'tcp', 'http', 'SF', 15478] ...
# Captured: [42.17053747177124, 'tcp', 'private', 'SF', 180304] ...
# Captured: [42.17028570175171, 'tcp', 'http', 'SF', 15544] ...
# Captured: [42.37596869468689, 'tcp', 'private', 'SF', 181119] ...
# Captured: [42.37618374824524, 'tcp', 'http', 'SF', 15610] ...
# Captured: [42.580811738967896, 'tcp', 'private', 'SF', 181934] ...
# Captured: [42.58079767227173, 'tcp', 'http', 'SF', 15676] ...
# Captured: [42.78757572174072, 'tcp', 'private', 'SF', 182750] ...
# Captured: [42.78797793388367, 'tcp', 'http', 'SF', 15742] ...
# Captured: [42.99249577522278, 'tcp', 'private', 'SF', 183565] ...
# Captured: [42.992255210876465, 'tcp', 'http', 'SF', 15808] ...
# Captured: [43.197964906692505, 'tcp', 'private', 'SF', 184381] ...
# Captured: [43.198365688323975, 'tcp', 'http', 'SF', 15874] ...
# Captured: [43.40496301651001, 'tcp', 'private', 'SF', 185198] ...
# Captured: [43.40484952926636, 'tcp', 'http', 'SF', 15940] ...
# Captured: [43.61040759086609, 'tcp', 'private', 'SF', 186013] ...
# Captured: [43.6103994846344, 'tcp', 'http', 'SF', 16006] ...
# Captured: [43.81491255760193, 'tcp', 'private', 'SF', 186827] ...
# Captured: [43.81491279602051, 'tcp', 'http', 'SF', 16072] ...
# Captured: [44.01943588256836, 'tcp', 'private', 'SF', 187642] ...
# Captured: [44.019426107406616, 'tcp', 'http', 'SF', 16138] ...
# Captured: [44.22379541397095, 'tcp', 'private', 'SF', 188458] ...
# Captured: [44.22379183769226, 'tcp', 'http', 'SF', 16204] ...
# Captured: [44.42840933799744, 'tcp', 'private', 'SF', 189273] ...
# Captured: [44.42857813835144, 'tcp', 'http', 'SF', 16270] ...
# Captured: [44.63515257835388, 'tcp', 'private', 'SF', 190088] ...
# Captured: [44.63516402244568, 'tcp', 'http', 'SF', 16336] ...
# Captured: [44.840840578079224, 'tcp', 'private', 'SF', 190903] ...
# Captured: [44.84092712402344, 'tcp', 'http', 'SF', 16402] ...
# Captured: [45.051618576049805, 'tcp', 'private', 'SF', 676] ...
# Captured: [45.05714988708496, 'tcp', 'private', 'SF', 10746] ...
# Captured: [45.05780005455017, 'tcp', 'private', 'SF', 742] ...
# Captured: [45.05996012687683, 'tcp', 'private', 'SF', 13224] ...
# Captured: [45.06240439414978, 'tcp', 'private', 'SF', 808] ...
# Captured: [0.0, 'tcp', 'http', 'S0', 74] ...
# Captured: [0.0, 'tcp', 'private', 'OTH', 74] ...
# Captured: [0.004071235656738281, 'tcp', 'http', 'SF', 140] ...
# Captured: [0.005296468734741211, 'tcp', 'http', 'SF', 324] ...
# Captured: [0.005035877227783203, 'tcp', 'private', 'SF', 140] ...
# Captured: [0.0, 'tcp', 'http', 'S0', 74] ...
# Captured: [0.0, 'tcp', 'private', 'OTH', 74] ...
# Captured: [0.002246379852294922, 'tcp', 'http', 'SF', 140] ...
# Captured: [0.004752159118652344, 'tcp', 'http', 'SF', 991] ...
# Captured: [0.005675792694091797, 'tcp', 'private', 'SF', 140] ...
# Captured: [0.0, 'tcp', 'http', 'S0', 74] ...
# Captured: [0.0, 'tcp', 'private', 'OTH', 74] ...
# Captured: [0.0028798580169677734, 'tcp', 'http', 'SF', 140] ...
# Captured: [0.004246950149536133, 'tcp', 'http', 'SF', 993] ...
# Captured: [0.003918170928955078, 'tcp', 'private', 'SF', 140] ...
# Captured: [0.025583505630493164, 'tcp', 'private', 'SF', 1601] ...
# Captured: [0.028199195861816406, 'tcp', 'http', 'SF', 390] ...
# Captured: [0.029466629028320312, 'tcp', 'http', 'SF', 456] ...
# Captured: [0.029301881790161133, 'tcp', 'private', 'SF', 1667] ...
# Captured: [0.0319066047668457, 'tcp', 'http', 'SF', 522] ...
# Captured: [45.06479501724243, 'tcp', 'private', 'SF', 192495] ...
# Captured: [45.06470084190369, 'tcp', 'http', 'SF', 16468] ...
# Captured: [0.01983165740966797, 'tcp', 'private', 'SF', 2401] ...
# Captured: [0.022846460342407227, 'tcp', 'http', 'SF', 1059] ...
# Captured: [0.03571915626525879, 'tcp', 'private', 'SF', 768] ...
# Captured: [0.02718496322631836, 'tcp', 'http', 'SF', 1125] ...
# Captured: [0.03982353210449219, 'tcp', 'http', 'SF', 1057] ...
# Captured: [0.029740095138549805, 'tcp', 'private', 'SF', 2467] ...
# Captured: [0.03252553939819336, 'tcp', 'http', 'SF', 1191] ...
# Captured: [0.0438539981842041, 'tcp', 'private', 'SF', 834] ...
# Captured: [0.046387672424316406, 'tcp', 'http', 'SF', 1123] ...
# Captured: [0.04655098915100098, 'tcp', 'private', 'SF', 900] ...
# Captured: [44.826024532318115, 'tcp', 'private', 'SF', 8762] ...
# Captured: [44.82631325721741, 'tcp', 'http', 'SF', 726] ...
# Captured: [45.249420166015625, 'tcp', 'private', 'SF', 194840] ...
# Captured: [45.24963188171387, 'tcp', 'http', 'SF', 16534] ...
# Captured: [45.45432996749878, 'tcp', 'private', 'SF', 195656] ...
# Captured: [45.45477366447449, 'tcp', 'http', 'SF', 16600] ...
# Captured: [45.65949988365173, 'tcp', 'private', 'SF', 196471] ...
# Captured: [45.65973234176636, 'tcp', 'http', 'SF', 16666] ...
# Captured: [45.86438465118408, 'tcp', 'private', 'SF', 197286] ...
# Captured: [45.86460876464844, 'tcp', 'http', 'SF', 16732] ...
# Captured: [46.07091498374939, 'tcp', 'private', 'SF', 198101] ...
# Captured: [46.071481227874756, 'tcp', 'http', 'SF', 16798] ...
# Captured: [46.276411056518555, 'tcp', 'private', 'SF', 198917] ...
# Captured: [46.27687215805054, 'tcp', 'http', 'SF', 16864] ...
# Captured: [46.017170906066895, 'tcp', 'private', 'SF', 9614] ...
# Captured: [46.01712656021118, 'tcp', 'http', 'SF', 792] ...
# Captured: [46.48170781135559, 'tcp', 'private', 'SF', 199860] ...
# Captured: [46.48241686820984, 'tcp', 'http', 'SF', 16930] ...
# Captured: [46.68682932853699, 'tcp', 'private', 'SF', 200675] ...
# Captured: [46.68728566169739, 'tcp', 'http', 'SF', 16996] ...
# Captured: [46.89402484893799, 'tcp', 'private', 'SF', 201490] ...
# Captured: [46.89484095573425, 'tcp', 'http', 'SF', 17062] ...
# Captured: [47.09942007064819, 'tcp', 'private', 'SF', 202305] ...
# Captured: [47.09994029998779, 'tcp', 'http', 'SF', 17128] ...
# Captured: [47.30437135696411, 'tcp', 'private', 'SF', 203120] ...
# Captured: [47.30460166931152, 'tcp', 'http', 'SF', 17194] ...
# Captured: [47.50919222831726, 'tcp', 'private', 'SF', 203935] ...
# Captured: [47.509501218795776, 'tcp', 'http', 'SF', 17260] ...
# Captured: [47.715758085250854, 'tcp', 'private', 'SF', 204751] ...
# Captured: [47.7165629863739, 'tcp', 'http', 'SF', 17326] ...
# Captured: [47.92063570022583, 'tcp', 'private', 'SF', 205566] ...
# Captured: [47.92107319831848, 'tcp', 'http', 'SF', 17392] ...
# Captured: [48.12733554840088, 'tcp', 'private', 'SF', 206381] ...
# Captured: [48.12788701057434, 'tcp', 'http', 'SF', 17458] ...
# Captured: [48.33297538757324, 'tcp', 'private', 'SF', 207196] ...
# Captured: [48.3333945274353, 'tcp', 'http', 'SF', 17524] ...
# Captured: [48.5377311706543, 'tcp', 'private', 'SF', 208010] ...
# Captured: [48.53786087036133, 'tcp', 'http', 'SF', 17590] ...
# Captured: [48.74265766143799, 'tcp', 'private', 'SF', 208824] ...
# Captured: [48.74288892745972, 'tcp', 'http', 'SF', 17656] ...
# Captured: [48.947503089904785, 'tcp', 'private', 'SF', 209639] ...
# Captured: [48.947601318359375, 'tcp', 'http', 'SF', 17722] ...
# Captured: [49.15203499794006, 'tcp', 'private', 'SF', 210456] ...
# Captured: [49.152021646499634, 'tcp', 'http', 'SF', 17788] ...
# Captured: [46.090309858322144, 'tcp', 'http', 'SF', 2507] ...
# Captured: [46.08866310119629, 'tcp', 'private', 'SF', 2636] ...
# Captured: [46.095510482788086, 'tcp', 'http', 'SF', 2573] ...
# Captured: [49.35703229904175, 'tcp', 'private', 'SF', 211463] ...
# Captured: [49.35715889930725, 'tcp', 'http', 'SF', 17854] ...
# Captured: [49.563292264938354, 'tcp', 'private', 'SF', 212278] ...
# Captured: [49.563316106796265, 'tcp', 'http', 'SF', 17920] ...
# Captured: [0.0, 'tcp', 'http', 'S0', 74] ...
# Captured: [0.0, 'tcp', 'private', 'OTH', 74] ...
# Captured: [0.0028569698333740234, 'tcp', 'http', 'SF', 140] ...
# Captured: [0.004181385040283203, 'tcp', 'http', 'SF', 988] ...
# Captured: [0.003833293914794922, 'tcp', 'private', 'SF', 140] ...
# Captured: [0.005116462707519531, 'tcp', 'private', 'SF', 599] ...
# Captured: [0.007445096969604492, 'tcp', 'http', 'SF', 1054] ...
# Captured: [0.008180379867553711, 'tcp', 'http', 'SF', 1120] ...
# Captured: [0.007464885711669922, 'tcp', 'private', 'SF', 665] ...
# Captured: [0.009801626205444336, 'tcp', 'http', 'SF', 1186] ...
# Captured: [49.76823902130127, 'tcp', 'private', 'SF', 213716] ...
# Captured: [49.768288373947144, 'tcp', 'http', 'SF', 17986] ...
# Captured: [49.97482442855835, 'tcp', 'private', 'SF', 214532] ...
# Captured: [49.97497606277466, 'tcp', 'http', 'SF', 18052] ...
# Captured: [50.17954897880554, 'tcp', 'private', 'SF', 215347] ...
# Captured: [50.179407596588135, 'tcp', 'http', 'SF', 18118] ...
# Captured: [50.385663986206055, 'tcp', 'private', 'SF', 216163] ...
# Captured: [50.38576412200928, 'tcp', 'http', 'SF', 18184] ...
# Captured: [50.59040856361389, 'tcp', 'private', 'SF', 216979] ...
# Captured: [50.590238094329834, 'tcp', 'http', 'SF', 18250] ...
# Captured: [50.79616189002991, 'tcp', 'private', 'SF', 217795] ...
# Captured: [50.79624009132385, 'tcp', 'http', 'SF', 18316] ...
# Captured: [51.00094556808472, 'tcp', 'private', 'SF', 218610] ...
# Captured: [51.00108313560486, 'tcp', 'http', 'SF', 18382] ...
# Captured: [51.20627522468567, 'tcp', 'private', 'SF', 219425] ...
# Captured: [51.20628905296326, 'tcp', 'http', 'SF', 18448] ...
# Captured: [51.41358184814453, 'tcp', 'private', 'SF', 220240] ...
# Captured: [51.41382598876953, 'tcp', 'http', 'SF', 18514] ...
# Captured: [48.458675146102905, 'tcp', 'http', 'SF', 2653] ...
# Captured: [48.458449840545654, 'tcp', 'private', 'SF', 2749] ...
# Captured: [48.46529030799866, 'tcp', 'http', 'SF', 2719] ...
# Captured: [51.618632793426514, 'tcp', 'private', 'SF', 221246] ...
# Captured: [51.61875605583191, 'tcp', 'http', 'SF', 18580] ...
# Captured: [51.82338857650757, 'tcp', 'private', 'SF', 222062] ...
# Captured: [51.823408126831055, 'tcp', 'http', 'SF', 18646] ...
# Captured: [52.02818155288696, 'tcp', 'private', 'SF', 222878] ...
# Captured: [52.02825617790222, 'tcp', 'http', 'SF', 18712] ...
# Captured: [52.233070373535156, 'tcp', 'private', 'SF', 223693] ...
# Captured: [52.233115434646606, 'tcp', 'http', 'SF', 18778] ...
# Captured: [52.43811011314392, 'tcp', 'private', 'SF', 224510] ...
# Captured: [52.438342571258545, 'tcp', 'http', 'SF', 18844] ...
# Captured: [52.64313769340515, 'tcp', 'private', 'SF', 225326] ...
# Captured: [52.64322352409363, 'tcp', 'http', 'SF', 18910] ...
# Captured: [52.84869313240051, 'tcp', 'private', 'SF', 226141] ...
# Captured: [52.849355697631836, 'tcp', 'http', 'SF', 18976] ...
# ...
# Captured: [180.12299489974976, 'tcp', 'private', 'SF', 759306] ...
# Captured: [180.1232852935791, 'tcp', 'http', 'SF', 60362] ...
# Captured: [0.0, 'tcp', 'http', 'S0', 74] ...
# Captured: [0.0, 'tcp', 'private', 'OTH', 74] ...
# Captured: [0.0038073062896728516, 'tcp', 'http', 'SF', 140] ...
# Captured: [0.005801200866699219, 'tcp', 'http', 'SF', 991] ...
# Captured: [0.0056879520416259766, 'tcp', 'private', 'SF', 140] ...
# Captured: [0.006913900375366211, 'tcp', 'private', 'SF', 768] ...
# Captured: [0.009857177734375, 'tcp', 'http', 'SF', 1057] ...
# Captured: [0.010841608047485352, 'tcp', 'http', 'SF', 1123] ...
# Captured: [0.009918928146362305, 'tcp', 'private', 'SF', 834] ...
# Captured: [0.012669086456298828, 'tcp', 'http', 'SF', 1189] ...
# Captured: [180.33045434951782, 'tcp', 'private', 'SF', 760741] ...
# Captured: [180.33126258850098, 'tcp', 'http', 'SF', 60428] ...
# Captured: [180.53993892669678, 'tcp', 'private', 'SF', 761558] ...
# Captured: [180.54030752182007, 'tcp', 'http', 'SF', 60494] ...
# Captured: [180.73553466796875, 'tcp', 'private', 'SF', 49126] ...
# Captured: [180.73621082305908, 'tcp', 'private', 'SF', 2490] ...
# Captured: [180.74765825271606, 'tcp', 'private', 'SF', 762508] ...
# Captured: [180.7481861114502, 'tcp', 'http', 'SF', 60560] ...
# Captured: [180.95664644241333, 'tcp', 'private', 'SF', 763324] ...
# Captured: [180.95670080184937, 'tcp', 'http', 'SF', 60626] ...
# Captured: [181.16639304161072, 'tcp', 'private', 'SF', 764141] ...
# Captured: [181.16665816307068, 'tcp', 'http', 'SF', 60692] ...
# Captured: [181.37467241287231, 'tcp', 'private', 'SF', 764958] ...
# Captured: [181.37506771087646, 'tcp', 'http', 'SF', 60758] ...
# Captured: [181.58352613449097, 'tcp', 'private', 'SF', 765775] ...
# Captured: [181.58384776115417, 'tcp', 'http', 'SF', 60824] ...
# Captured: [181.46349477767944, 'tcp', 'http', 'SF', 1518] ...
# Captured: [181.4659378528595, 'tcp', 'private', 'SF', 17527] ...
# Captured: [181.79071521759033, 'tcp', 'private', 'SF', 766721] ...
# Captured: [181.79101395606995, 'tcp', 'http', 'SF', 60890] ...
# Captured: [181.99882006645203, 'tcp', 'private', 'SF', 767538] ...
# Captured: [181.99935221672058, 'tcp', 'http', 'SF', 60956] ...
# Captured: [182.20802545547485, 'tcp', 'private', 'SF', 768355] ...
# Captured: [182.2086262702942, 'tcp', 'http', 'SF', 61022] ...
# Captured: [182.41557812690735, 'tcp', 'private', 'SF', 769171] ...
# Captured: [182.41607308387756, 'tcp', 'http', 'SF', 61088] ...
# Captured: [179.4703929424286, 'tcp', 'http', 'SF', 10134] ...
# Captured: [179.46667504310608, 'tcp', 'private', 'SF', 8896] ...
# Captured: [179.4691264629364, 'tcp', 'private', 'SF', 9009] ...
# Captured: [179.47599983215332, 'tcp', 'http', 'SF', 10200] ...
# Captured: [182.62471389770508, 'tcp', 'private', 'SF', 770246] ...
# Captured: [182.62503910064697, 'tcp', 'http', 'SF', 61154] ...
# Captured: [182.83189988136292, 'tcp', 'private', 'SF', 771063] ...
# Captured: [182.83218455314636, 'tcp', 'http', 'SF', 61220] ...
# Captured: [179.7242136001587, 'tcp', 'http', 'SF', 10290] ...
# Captured: [179.72423434257507, 'tcp', 'private', 'SF', 9122] ...
# Captured: [179.73122239112854, 'tcp', 'http', 'SF', 10356] ...
# Captured: [183.0400996208191, 'tcp', 'private', 'SF', 772073] ...
# Captured: [183.04038763046265, 'tcp', 'http', 'SF', 61286] ...
# Captured: [183.2493598461151, 'tcp', 'private', 'SF', 772889] ...
# Captured: [183.2502748966217, 'tcp', 'http', 'SF', 61352] ...
# Captured: [183.4567677974701, 'tcp', 'private', 'SF', 773704] ...
# Captured: [183.45707726478577, 'tcp', 'http', 'SF', 61418] ...
# Captured: [183.66555333137512, 'tcp', 'private', 'SF', 774520] ...
# Captured: [183.66587901115417, 'tcp', 'http', 'SF', 61484] ...
# Captured: [183.87374019622803, 'tcp', 'private', 'SF', 775337] ...
# Captured: [183.87407445907593, 'tcp', 'http', 'SF', 61550] ...
# Captured: [184.0827977657318, 'tcp', 'private', 'SF', 776154] ...
# Captured: [184.08326125144958, 'tcp', 'http', 'SF', 61616] ...
# Captured: [184.2901735305786, 'tcp', 'private', 'SF', 776970] ...
# Captured: [184.29053568840027, 'tcp', 'http', 'SF', 61682] ...
# Captured: [184.49962711334229, 'tcp', 'private', 'SF', 777786] ...
# Captured: [184.50025415420532, 'tcp', 'http', 'SF', 61748] ...
# Captured: [184.71044969558716, 'tcp', 'private', 'SF', 778603] ...
# Captured: [184.71081042289734, 'tcp', 'http', 'SF', 61814] ...
# Captured: [184.9192464351654, 'tcp', 'private', 'SF', 779420] ...
# Captured: [184.9194097518921, 'tcp', 'http', 'SF', 61880] ...
# Captured: [185.12651872634888, 'tcp', 'private', 'SF', 780235] ...
# Captured: [185.12687587738037, 'tcp', 'http', 'SF', 61946] ...
# Captured: [185.33543300628662, 'tcp', 'private', 'SF', 781052] ...
# Captured: [185.33569979667664, 'tcp', 'http', 'SF', 62012] ...
# Captured: [185.5431571006775, 'tcp', 'private', 'SF', 781869] ...
# Captured: [185.54348802566528, 'tcp', 'http', 'SF', 62078] ...
# Captured: [185.75277066230774, 'tcp', 'private', 'SF', 782685] ...
# Captured: [185.75317096710205, 'tcp', 'http', 'SF', 62144] ...
# Captured: [185.78508067131042, 'tcp', 'http', 'SF', 62575] ...
# Captured: [185.82670378684998, 'tcp', 'private', 'SF', 782751] ...
# Captured: [185.96053838729858, 'tcp', 'private', 'SF', 783700] ...
# Captured: [185.9993691444397, 'tcp', 'http', 'SF', 62641] ...
# Captured: [186.16938424110413, 'tcp', 'private', 'SF', 784516] ...
# Captured: [186.16970944404602, 'tcp', 'http', 'SF', 62707] ...
# Captured: [186.37710165977478, 'tcp', 'private', 'SF', 785333] ...
# Captured: [186.3771095275879, 'tcp', 'http', 'SF', 62773] ...
# Captured: [186.58724093437195, 'tcp', 'private', 'SF', 786149] ...
# Captured: [186.58751368522644, 'tcp', 'http', 'SF', 62839] ...
# Captured: [186.7951934337616, 'tcp', 'private', 'SF', 786966] ...
# Captured: [186.7954511642456, 'tcp', 'http', 'SF', 62905] ...
# Captured: [0.0, 'tcp', 'http', 'S0', 74] ...
# Captured: [0.0, 'tcp', 'private', 'OTH', 74] ...
# Captured: [0.003263711929321289, 'tcp', 'http', 'SF', 140] ...
# Captured: [0.004830598831176758, 'tcp', 'http', 'SF', 993] ...
# Captured: [0.0047605037689208984, 'tcp', 'private', 'SF', 140] ...
# Captured: [0.007462263107299805, 'tcp', 'private', 'SF', 2402] ...
# Captured: [0.010254383087158203, 'tcp', 'http', 'SF', 1059] ...
# Captured: [0.01128697395324707, 'tcp', 'http', 'SF', 1125] ...
# Captured: [0.010373592376708984, 'tcp', 'private', 'SF', 2468] ...
# Captured: [0.013111352920532227, 'tcp', 'http', 'SF', 1191] ...
# Captured: [187.002769947052, 'tcp', 'private', 'SF', 788403] ...
# Captured: [187.00292444229126, 'tcp', 'http', 'SF', 62971] ...
# Captured: [187.21777749061584, 'tcp', 'private', 'SF', 789218] ...
# Captured: [187.21865010261536, 'tcp', 'http', 'SF', 63037] ...
# Captured: [187.42817974090576, 'tcp', 'private', 'SF', 790035] ...
# Captured: [187.42858457565308, 'tcp', 'http', 'SF', 63103] ...
# Captured: [187.64044547080994, 'tcp', 'private', 'SF', 790852] ...
# Captured: [187.64148378372192, 'tcp', 'http', 'SF', 63169] ...
# Captured: [187.85326409339905, 'tcp', 'private', 'SF', 791669] ...
# Captured: [187.8539047241211, 'tcp', 'http', 'SF', 63235] ...
# Captured: [188.06301712989807, 'tcp', 'private', 'SF', 792485] ...
# Captured: [188.06368851661682, 'tcp', 'http', 'SF', 63301] ...
# Captured: [188.27558970451355, 'tcp', 'private', 'SF', 793302] ...
# Captured: [188.27638339996338, 'tcp', 'http', 'SF', 63367] ...
# Captured: [188.48802995681763, 'tcp', 'private', 'SF', 794119] ...
# Captured: [188.48883700370789, 'tcp', 'http', 'SF', 63433] ...
# Captured: [188.69929385185242, 'tcp', 'private', 'SF', 794936] ...
# Captured: [188.7001051902771, 'tcp', 'http', 'SF', 63499] ...
# Captured: [188.90767908096313, 'tcp', 'private', 'SF', 795752] ...
# Captured: [188.90797209739685, 'tcp', 'http', 'SF', 63565] ...
# Captured: [189.11742210388184, 'tcp', 'private', 'SF', 796569] ...
# Captured: [189.1178572177887, 'tcp', 'http', 'SF', 63631] ...
# Captured: [189.32509326934814, 'tcp', 'private', 'SF', 797385] ...
# Captured: [189.32533884048462, 'tcp', 'http', 'SF', 63697] ...
# Captured: [189.53436136245728, 'tcp', 'private', 'SF', 798202] ...
# Captured: [189.53532481193542, 'tcp', 'http', 'SF', 63763] ...
# Captured: [189.7440001964569, 'tcp', 'private', 'SF', 799019] ...
# Captured: [189.7444031238556, 'tcp', 'http', 'SF', 63829] ...
# Captured: [189.95171475410461, 'tcp', 'private', 'SF', 799834] ...
# Captured: [189.9522213935852, 'tcp', 'http', 'SF', 63895] ...
# Captured: [190.16032910346985, 'tcp', 'private', 'SF', 800650] ...
# Captured: [190.1605429649353, 'tcp', 'http', 'SF', 63961] ...
# Captured: [190.36964392662048, 'tcp', 'private', 'SF', 801466] ...
# Captured: [190.36989831924438, 'tcp', 'http', 'SF', 64027] ...
# Captured: [190.5771803855896, 'tcp', 'private', 'SF', 802283] ...
# Captured: [190.57744598388672, 'tcp', 'http', 'SF', 64093] ...
# Captured: [0.0, 'tcp', 'http', 'S0', 74] ...
# Captured: [0.0, 'tcp', 'private', 'OTH', 74] ...
# Captured: [0.003186941146850586, 'tcp', 'http', 'SF', 140] ...
# Captured: [0.004728078842163086, 'tcp', 'http', 'SF', 990] ...
# Captured: [0.004415035247802734, 'tcp', 'private', 'SF', 140] ...
# Captured: [0.005837917327880859, 'tcp', 'private', 'SF', 768] ...
# Captured: [0.008914470672607422, 'tcp', 'http', 'SF', 1056] ...
# Captured: [0.010088682174682617, 'tcp', 'http', 'SF', 1122] ...
# Captured: [0.009280204772949219, 'tcp', 'private', 'SF', 834] ...
# Captured: [0.01182413101196289, 'tcp', 'http', 'SF', 1188] ...
# Captured: [190.7858567237854, 'tcp', 'private', 'SF', 803718] ...
# Captured: [190.78621697425842, 'tcp', 'http', 'SF', 64159] ...
# Captured: [190.99296832084656, 'tcp', 'private', 'SF', 804534] ...
# Captured: [190.99335145950317, 'tcp', 'http', 'SF', 64225] ...
# Captured: [191.20153045654297, 'tcp', 'private', 'SF', 805351] ...
# Captured: [191.20228028297424, 'tcp', 'http', 'SF', 64291] ...
# Captured: [188.16069173812866, 'tcp', 'http', 'SF', 10439] ...
# Captured: [188.16384935379028, 'tcp', 'http', 'SF', 10519] ...
# Captured: [188.1661732196808, 'tcp', 'http', 'SF', 10602] ...
# Captured: [188.16234064102173, 'tcp', 'private', 'SF', 9188] ...
# Captured: [188.1646270751953, 'tcp', 'private', 'SF', 9301] ...
# Captured: [188.1720609664917, 'tcp', 'http', 'SF', 10668] ...
# Captured: [188.16755032539368, 'tcp', 'private', 'SF', 9414] ...
# Captured: [188.17423701286316, 'tcp', 'http', 'SF', 10734] ...
# Captured: [188.16940641403198, 'tcp', 'private', 'SF', 9527] ...
# Captured: [188.17599630355835, 'tcp', 'http', 'SF', 10800] ...
# Captured: [191.41083025932312, 'tcp', 'private', 'SF', 806813] ...
# Captured: [191.41113185882568, 'tcp', 'http', 'SF', 64357] ...
# Captured: [191.61859512329102, 'tcp', 'private', 'SF', 807630] ...
# Captured: [191.61912417411804, 'tcp', 'http', 'SF', 64423] ...
# Captured: [191.82766962051392, 'tcp', 'private', 'SF', 808447] ...
# Captured: [191.82785296440125, 'tcp', 'http', 'SF', 64489] ...
# Captured: [192.03644728660583, 'tcp', 'private', 'SF', 809264] ...
# Captured: [192.03676176071167, 'tcp', 'http', 'SF', 64555] ...
# Captured: [192.24437880516052, 'tcp', 'private', 'SF', 810081] ...
# Captured: [192.24480605125427, 'tcp', 'http', 'SF', 64621] ...
# Captured: [189.27166438102722, 'tcp', 'http', 'SF', 10884] ...
# Captured: [189.27051997184753, 'tcp', 'private', 'SF', 9640] ...
# Captured: [189.27772569656372, 'tcp', 'http', 'SF', 10950] ...
# Captured: [192.4549524784088, 'tcp', 'private', 'SF', 811092] ...
# Captured: [192.45501565933228, 'tcp', 'http', 'SF', 64687] ...
# Captured: [192.66493892669678, 'tcp', 'private', 'SF', 811908] ...
# Captured: [192.66502332687378, 'tcp', 'http', 'SF', 64753] ...
# Captured: [192.87999820709229, 'tcp', 'private', 'SF', 812725] ...
# Captured: [192.880446434021, 'tcp', 'http', 'SF', 64819] ...
# Captured: [193.08767247200012, 'tcp', 'private', 'SF', 813540] ...
# Captured: [193.0880889892578, 'tcp', 'http', 'SF', 64885] ...
# Captured: [193.29980564117432, 'tcp', 'private', 'SF', 814356] ...
# Captured: [193.3001787662506, 'tcp', 'http', 'SF', 64951] ...
# Captured: [193.50808143615723, 'tcp', 'private', 'SF', 815172] ...
# Captured: [193.50874018669128, 'tcp', 'http', 'SF', 65017] ...
# Captured: [190.52974128723145, 'tcp', 'http', 'SF', 11030] ...
# Captured: [190.52939867973328, 'tcp', 'private', 'SF', 9753] ...
# Captured: [190.5363495349884, 'tcp', 'http', 'SF', 11096] ...
# Captured: [193.71894669532776, 'tcp', 'private', 'SF', 816182] ...
# Captured: [193.71917390823364, 'tcp', 'http', 'SF', 65083] ...
# Captured: [190.63829898834229, 'tcp', 'http', 'SF', 11176] ...
# Captured: [190.63667464256287, 'tcp', 'private', 'SF', 9866] ...
# Captured: [190.64374017715454, 'tcp', 'http', 'SF', 11242] ...
# Captured: [193.92596220970154, 'tcp', 'private', 'SF', 817193] ...
# Captured: [193.92595529556274, 'tcp', 'http', 'SF', 65149] ...
# Captured: [194.13559556007385, 'tcp', 'private', 'SF', 818010] ...
# Captured: [194.13583850860596, 'tcp', 'http', 'SF', 65215] ...
# Captured: [194.34424996376038, 'tcp', 'private', 'SF', 818827] ...
# Captured: [194.34447717666626, 'tcp', 'http', 'SF', 65281] ...
# Captured: [194.55187010765076, 'tcp', 'private', 'SF', 819644] ...
# Captured: [194.55192136764526, 'tcp', 'http', 'SF', 65347] ...
# Captured: [194.76174449920654, 'tcp', 'private', 'SF', 820461] ...
# Captured: [194.76213669776917, 'tcp', 'http', 'SF', 65413] ...
# Captured: [191.8066692352295, 'tcp', 'http', 'SF', 11325] ...
# Captured: [191.80513525009155, 'tcp', 'private', 'SF', 9979] ...
# Captured: [191.81213116645813, 'tcp', 'http', 'SF', 11391] ...
# Captured: [194.96959567070007, 'tcp', 'private', 'SF', 821471] ...
# Captured: [194.9703013896942, 'tcp', 'http', 'SF', 65479] ...
# Captured: [195.1786766052246, 'tcp', 'private', 'SF', 822287] ...
# Captured: [195.17887902259827, 'tcp', 'http', 'SF', 65545] ...
# Captured: [195.38618087768555, 'tcp', 'private', 'SF', 823103] ...
# Captured: [195.38645911216736, 'tcp', 'http', 'SF', 65611] ...
# Captured: [195.58276629447937, 'tcp', 'private', 'SF', 2556] ...
# Captured: [195.58480978012085, 'tcp', 'private', 'SF', 49192] ...
# Captured: [195.60175848007202, 'tcp', 'private', 'SF', 2729] ...
# Captured: [195.6044328212738, 'tcp', 'private', 'SF', 53354] ...
# Captured: [195.6053512096405, 'tcp', 'private', 'SF', 2795] ...
# Captured: [195.60826873779297, 'tcp', 'private', 'SF', 59926] ...
# Captured: [195.6120491027832, 'tcp', 'private', 'SF', 2861] ...
# Captured: [195.6143443584442, 'tcp', 'private', 'SF', 59999] ...
# Captured: [195.61494636535645, 'tcp', 'private', 'SF', 2927] ...
# Captured: [0.0, 'tcp', 'http', 'S0', 74] ...
# Captured: [0.0, 'tcp', 'private', 'OTH', 74] ...
# Captured: [0.0033371448516845703, 'tcp', 'http', 'SF', 140] ...
# Captured: [0.009005546569824219, 'tcp', 'http', 'SF', 324] ...
# Captured: [0.009467363357543945, 'tcp', 'private', 'SF', 140] ...
# Captured: [0.011149168014526367, 'tcp', 'private', 'SF', 515] ...
# Captured: [0.013831853866577148, 'tcp', 'http', 'SF', 390] ...
# Captured: [0.015295743942260742, 'tcp', 'http', 'SF', 456] ...
# Captured: [0.015530586242675781, 'tcp', 'private', 'SF', 581] ...
# Captured: [0.018122434616088867, 'tcp', 'http', 'SF', 522] ...
# Captured: [195.60371661186218, 'tcp', 'private', 'SF', 824610] ...
# Captured: [195.6036992073059, 'tcp', 'http', 'SF', 65677] ...
# Captured: [195.79874801635742, 'tcp', 'private', 'SF', 825948] ...
# Captured: [195.79905223846436, 'tcp', 'http', 'SF', 65743] ...
# Captured: [196.00852274894714, 'tcp', 'private', 'SF', 826765] ...
# Captured: [196.00921416282654, 'tcp', 'http', 'SF', 65809] ...
# Captured: [196.21620631217957, 'tcp', 'private', 'SF', 827582] ...
# Captured: [196.21655988693237, 'tcp', 'http', 'SF', 65875] ...
# Captured: [196.4253590106964, 'tcp', 'private', 'SF', 828399] ...
# Captured: [196.42559266090393, 'tcp', 'http', 'SF', 65941] ...
# Captured: [196.63421821594238, 'tcp', 'private', 'SF', 829215] ...
# Captured: [196.63450503349304, 'tcp', 'http', 'SF', 66007] ...
# Captured: [196.843519449234, 'tcp', 'private', 'SF', 830032] ...
# Captured: [196.8435583114624, 'tcp', 'http', 'SF', 66073] ...
# Captured: [197.0523602962494, 'tcp', 'private', 'SF', 830846] ...
# Captured: [197.05268692970276, 'tcp', 'http', 'SF', 66139] ...
# Captured: [0.0, 'tcp', 'http', 'S0', 74] ...
# Captured: [0.0, 'tcp', 'private', 'OTH', 74] ...

# %%
# rf_row = MyRandomForest(n_trees=5, max_depth=None, n_features=None)

# # Fit the model on your dataset
# rf_row.fit(x_train, y_train)

# %%
# # Updated Real-Time NIDS Feature Extraction Script

# !pip install scapy psutil pyinotify > /dev/null

# import csv
# import os
# from scapy.all import sniff, IP, TCP, UDP
# from collections import defaultdict, deque
# import time
# import socket
# import psutil
# import threading
# import pandas as pd

# csv_file_path = "/content/real_time_nids_features.csv"
# csv_header = [
#     "duration", "protocol_type", "service", "flag", "src_bytes", "dst_bytes", "land",
#     "wrong_fragment", "urgent", "hot", "num_failed_logins", "logged_in", "num_compromised",
#     "root_shell", "su_attempted", "num_root", "num_file_creations", "num_shells",
#     "num_access_files", "num_outbound_cmds", "is_host_login", "is_guest_login",
#     "count", "srv_count", "serror_rate", "srv_serror_rate", "rerror_rate",
#     "srv_rerror_rate", "same_srv_rate", "diff_srv_rate", "srv_diff_host_rate",
#     "dst_host_count", "dst_host_srv_count", "dst_host_same_srv_rate",
#     "dst_host_diff_srv_rate", "dst_host_same_src_port_rate",
#     "dst_host_srv_diff_host_rate", "dst_host_serror_rate",
#     "dst_host_srv_serror_rate", "dst_host_rerror_rate",
#     "dst_host_srv_rerror_rate"
# ]

# if not os.path.exists(csv_file_path):
#     with open(csv_file_path, mode='w', newline='') as f:
#         writer = csv.writer(f)
#         writer.writerow(csv_header)

# flows = defaultdict(lambda: {
#     'start_time': None,
#     'end_time': None,
#     'src_bytes': 0,
#     'dst_bytes': 0,
#     'count': 0,
#     'services': set(),
#     'dst_hosts': set(),
#     'ports': set(),
#     'tcp_flags': [],
#     'logged_in': 0,
# })

# window = deque(maxlen=1000)
# window_duration = 2

# num_login_attempts = 0
# num_shell_activities = 0
# num_file_operations = 0


# def monitor_logins():
#     global num_login_attempts
#     while True:
#         try:
#             users = psutil.users()
#             num_login_attempts = len(users)
#         except Exception:
#             num_login_attempts = 0
#         time.sleep(2)


# def monitor_shell():
#     global num_shell_activities
#     while True:
#         try:
#             procs = [p.name() for p in psutil.process_iter(['name']) if p.name() in ["bash", "sh", "zsh"]]
#             num_shell_activities = len(procs)
#         except Exception:
#             num_shell_activities = 0
#         time.sleep(2)


# def monitor_file_creations():
#     global num_file_operations
#     before = set(os.listdir('/tmp'))
#     while True:
#         time.sleep(2)
#         after = set(os.listdir('/tmp'))
#         created = after - before
#         num_file_operations = len(created)
#         before = after


# def map_port_to_service(port):
#     common_ports = {
#         20: 'ftp_data', 21: 'ftp', 22: 'ssh', 23: 'telnet', 25: 'smtp',
#         53: 'domain', 69: 'tftp_u', 80: 'http', 110: 'pop_3', 443: 'https',
#         513: 'login', 514: 'shell', 8080: 'http'
#     }
#     return common_ports.get(port, 'private' if port >= 1024 else 'other')


# def map_flags_to_dataset(flag):
#     if flag in ['PA', 'A', 'P', 'FA', 'F']:
#         return 'SF'
#     elif flag == 'S':
#         return 'S0'
#     elif flag in ['R', 'RA']:
#         return 'REJ'
#     else:
#         return 'OTH'


# def extract_features(pkt):
#     if not IP in pkt:
#         return

#     ip = pkt[IP]
#     proto = pkt.proto
#     now = time.time()

#     sport = pkt.sport if TCP in pkt or UDP in pkt else 0
#     dport = pkt.dport if TCP in pkt or UDP in pkt else 0
#     key = (ip.src, ip.dst, sport, dport, proto)

#     flow = flows[key]
#     if flow['start_time'] is None:
#         flow['start_time'] = now
#     flow['end_time'] = now

#     flow['count'] += 1
#     size = len(pkt)

#     if ip.src == key[0]:
#         flow['src_bytes'] += size
#     else:
#         flow['dst_bytes'] += size

#     flow['services'].add(map_port_to_service(dport))
#     flow['dst_hosts'].add(ip.dst)
#     flow['ports'].add(dport)

#     if TCP in pkt:
#         tcp = pkt[TCP]
#         flow['tcp_flags'].append(tcp.flags)
#         if tcp.flags == "S":
#             flow['logged_in'] = 0
#         if tcp.flags == "PA":
#             flow['logged_in'] = 1

#     window.append({
#         'src': ip.src, 'dst': ip.dst, 'proto': proto,
#         'service': map_port_to_service(dport), 'timestamp': now
#     })

#     duration = flow['end_time'] - flow['start_time']
#     protocol_type = {6: 'tcp', 17: 'udp', 1: 'icmp'}.get(proto, 'other')
#     service = list(flow['services'])[0] if flow['services'] else '0'
#     raw_flag = flow['tcp_flags'][-1] if flow['tcp_flags'] else '0'
#     flag = map_flags_to_dataset(str(raw_flag))
#     src_bytes = flow['src_bytes']
#     dst_bytes = flow['dst_bytes']
#     land = 1 if ip.src == ip.dst and sport == dport else 0

#     wrong_fragment = 0
#     urgent = 0
#     hot = 0
#     num_failed_logins = 0
#     logged_in = flow['logged_in']
#     num_compromised = 0
#     root_shell = 0
#     su_attempted = 0
#     num_root = 0
#     num_file_creations = 0
#     num_shells = 0
#     num_access_files = 0
#     num_outbound_cmds = 0
#     is_host_login = 0
#     is_guest_login = 0

#     recent = [w for w in window if now - w['timestamp'] <= window_duration]
#     count = len([w for w in recent if w['dst'] == ip.dst])
#     srv_count = len([w for w in recent if w['dst'] == ip.dst and w['service'] == service])

#     same_srv_rate = srv_count / count if count else 0
#     diff_srv_rate = 1 - same_srv_rate

#     features = [
#         duration, protocol_type, service, flag, src_bytes, dst_bytes, land,
#         wrong_fragment, urgent, hot, num_failed_logins, logged_in, num_compromised,
#         root_shell, su_attempted, num_root, num_file_creations, num_shells,
#         num_access_files, num_outbound_cmds, is_host_login, is_guest_login,
#         count, srv_count, serror_rate, srv_serror_rate, rerror_rate,
#         srv_rerror_rate, same_srv_rate, diff_srv_rate, srv_diff_host_rate,
#         dst_host_count, dst_host_srv_count, dst_host_same_srv_rate,
#         dst_host_diff_srv_rate, dst_host_same_src_port_rate,
#         dst_host_srv_diff_host_rate, dst_host_serror_rate,
#         dst_host_srv_serror_rate, dst_host_rerror_rate,
#         dst_host_srv_rerror_rate
#     ]

#     with open(csv_file_path, mode='a', newline='') as f:
#         writer = csv.writer(f)
#         writer.writerow(features)

#     print("Captured:", features[:5], "...")


# def start_sniffing(iface="eth0"):
#     print("[*] Capturing packets & writing to:", csv_file_path)
#     sniff(iface=iface, prn=extract_features, store=0)


# if __name__ == "__main__":
#     threading.Thread(target=monitor_logins, daemon=True).start()
#     threading.Thread(target=monitor_shell, daemon=True).start()
#     threading.Thread(target=monitor_file_creations, daemon=True).start()

#     start_sniffing("eth0")

# %%
import pandas as pd
from collections import Counter
from sklearn.preprocessing import LabelEncoder

# Load unlabeled data
unlabeled_data = pd.read_csv("real_time_nids_features.csv")
for col in unlabeled_data.columns:
    if unlabeled_data[col].dtype == 'object':
        le = LabelEncoder()
        unlabeled_data[col] = le.fit_transform(unlabeled_data[col].astype(str))
# model.predict(unlabeled_data)
preds = model.predict(unlabeled_data)

# Count predictions
prediction_counts = Counter(preds)
print(" Prediction Count:", dict(prediction_counts))

# Final Say
if prediction_counts:
    final_class = prediction_counts.most_common(1)[0][0]
    if final_class == 1 or final_class == 'anomaly':
        print(" Final Say: Anomaly Detected")
    else:
        print("Final Say: Normal Behavior")
else:
    print(" Final Say: No predictions made. Check your data or model.")
# Out:
#  Prediction Count: {np.int64(0): 2582, np.int64(1): 236}
# Final Say: Normal Behavior

# %%
# new_preds = rf_row.predict(unlabeled_data)

# # Count predictions
# prediction_counts = Counter(new_preds)
# print("🔍 Prediction Count:", dict(prediction_counts))

# # Final Say
# if prediction_counts:
#     final_class = prediction_counts.most_common(1)[0][0]
#     if final_class == 1 or final_class == 'anomaly':
#         print(" Final Say: Anomaly Detected")
#     else:
#         print("Final Say: Normal Behavior")
# else:
#     print(" Final Say: No predictions made. Check your data or model.")
